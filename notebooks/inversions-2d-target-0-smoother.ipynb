# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import time
import os
import pickle

from concurrent.futures import ProcessPoolExecutor, as_completed, ThreadPoolExecutor


import discretize 
from simpeg import maps
from simpeg.electromagnetics import time_domain as tdem
from simpeg import (
    maps,
    Data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils,
)

from simpeg.utils.solver_utils import get_default_solver

from simpeg.meta import MultiprocessingMetaSimulation #DaskMetaSimulation

# %%
Solver = get_default_solver()
Solver
# Out:
# pymatsolver.direct.pardiso.Pardiso

# %%
data_directory = "./synthetic-data-2d-20m"

# %% [markdown]
# # set up models and mesh

# %%
sigma_air = 1e-8
rho_back = 500
sigma_back = 1./rho_back

# %%
files = [f for f in os.listdir(data_directory) if os.path.isfile(os.path.join(data_directory, f))]
files
# Out:
# ['dpred_background.npy',
#  'dpred_target_0.npy',
#  'dpred_target_15.npy',
#  'true_models3d.pkl',
#  'log_conductivity_models_2d.pkl',
#  'dpred_target_45.npy',
#  'rx_times.npy',
#  'mesh.json',
#  'dpred_target_30.npy',
#  'rx_locs.npy']

# %%
with open(f"{data_directory}/true_models3d.pkl", "rb") as f:
    true_models = pickle.load(f)

# %%
with open(f"{data_directory}/log_conductivity_models_2d.pkl", "rb") as f:
    log_conductivity_models_2d = pickle.load(f)

# %%
rx_times = np.load(f"{data_directory}/rx_times.npy")
rx_locs = np.load(f"{data_directory}/rx_locs.npy")

# %%
mesh = discretize.load_mesh(f"{data_directory}/mesh.json")

# %%
mesh
# Out:
#   TensorMesh: 14,280 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     35     -1,365.13      1,365.13     20.00    429.88    1.55
#    y     17     -1,185.13      1,185.13     20.00    429.88    1.55
#    z     24     -1,335.13      1,175.13     20.00    429.88    1.55

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 2)) 

plt.colorbar(
    mesh.plot_slice(
        true_models["target_45"], 
        grid=True, 
        normal="y",
        pcolor_opts={"norm":LogNorm(1e-6, 1e-1)},
        grid_opts={"color":"k", "lw":0.5},
        ax=ax)[0], 
    ax=ax
)

ax.set_xlim(600*np.r_[-1, 1])
ax.set_ylim(np.r_[-300, 50])

ax.plot(rx_locs[:, 0], rx_locs[:, 2], "ro")
ax.set_aspect(1)

# %%
mesh_2d = discretize.TensorMesh(
    [mesh.h[0], mesh.h[2]], origin=np.r_[mesh.origin[0], mesh.origin[2]]
)

# %%
inds_2d_slice = (mesh.cell_centers[:, 1] < mesh.h[0].min()/2) & (mesh.cell_centers[:, 1] > -mesh.h[0].min()/2)

# %%
# def get_sim():
    # set up survey

def get_sim(
    mesh=mesh, mesh_2d=mesh_2d, rx_locs=rx_locs, rx_times=rx_times, sigma_air=sigma_air
):
    source_list = []
    
    for i in range(rx_locs.shape[0]): 
        rx = tdem.receivers.PointMagneticFluxTimeDerivative(rx_locs[i, :], rx_times, orientation="z")
        src = tdem.sources.CircularLoop(
            receiver_list=[rx], location=rx_locs[i, :], orientation="z", radius=10, 
            waveform=tdem.sources.StepOffWaveform()
        )
        source_list.append(src)
    
    survey = tdem.Survey(source_list)
    
    # create simulation 
    time_steps = [
        (1e-6, 10), 
        (3e-6, 10), 
        (1e-5, 10), 
        (3e-5, 20), 
        (1e-4, 20), 
        # (3e-4, 20)
    ]   
    active_cells = mesh_2d.cell_centers[:, 1] < 0
    mapping = maps.ComboMap([
        maps.ExpMap(mesh), 
        maps.Surject2Dto3D(mesh), 
        maps.InjectActiveCells(mesh_2d, active_cells=active_cells, value_inactive=np.log(sigma_air))
    ])
    simulation = tdem.simulation.Simulation3DElectricField(
        mesh=mesh,
        survey=survey,
        time_steps=time_steps,
        solver=Solver,
        sigmaMap=mapping, 
        solver_opts={}
    )
    return simulation

# %% [markdown]
# ## load data

# %%
key_invert = "target_0"

# %%
dpred_dict = {}
for key in ["background", key_invert]: #true_models.keys(): 
    dpred_dict[key] = np.load(f"{data_directory}/dpred_{key}.npy")

# %%
fig, ax = plt.subplots(1, 1) 

ax.semilogy(
    rx_locs[:, 0], -dpred_dict["background"].reshape(rx_locs.shape[0], len(rx_times)), color="k", lw=1, alpha=0.5
);
ax.semilogy(
    rx_locs[: ,0], -dpred_dict[key_invert].reshape(rx_locs.shape[0], len(rx_times)), "C0-o", lw=1, ms=2
);

# %%
ind = 10
rx_locs[ind, :]
# Out:
# array([ 0.,  0., 30.])

# %%
rel_error=0.1
noise_floor=1e-11

# %%
fig, ax = plt.subplots(1, 1) 

data_plot = -dpred_dict[key_invert].reshape(rx_locs.shape[0], len(rx_times))[ind, :]
ax.errorbar(rx_times, data_plot, yerr=np.abs(data_plot)*rel_error + noise_floor)

ax.loglog(
    rx_times, -dpred_dict["background"].reshape(rx_locs.shape[0], len(rx_times))[ind, :], color="k"
)

# %%
sim = get_sim(mesh, mesh_2d)

# %%
# set up 3D inversion 
def create_inversion(key_invert, mesh=mesh, mesh_2d=mesh_2d): 
    relative_error=0.1
    noise_floor=1e-11
    # alpha_s = 1e-1
    # alpha_x = 1
    rho_back = 500
    # beta0 = 10

    dobs = dpred_dict[key_invert]
    sim = get_sim(mesh, mesh_2d)
    data_invert = Data(
        dobs=dobs, survey=sim.survey, standard_deviation=np.abs(dobs)*relative_error + noise_floor
    )
    
    dmis = data_misfit.L2DataMisfit(simulation=sim, data=data_invert)
    reg = regularization.WeightedLeastSquares(
        mesh_2d, 
        active_cells=sim.sigmaMap.maps[2].active_cells,
        alpha_s = (1/20**2)*10,
        alpha_x = 1, 
        alpha_y = 1,
        # alpha_s=1e-6, 
        # alpha_x=alpha_x, 
        # reference_model=np.log(1./rho_back),
        # norms=norms
    )
    
    opt = optimization.InexactGaussNewton(maxIter=10, maxIterCG=30, tolCG=1e-3)
    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt)
    
    # Defining a starting value for the trade-off parameter (beta) between the data
    # misfit and the regularization.
    starting_beta = directives.BetaEstimate_ByEig(beta0_ratio=10)
    
    cool_beta = directives.BetaSchedule(coolingFactor=1.5, coolingRate=1)
    
    # Update the preconditionner
    # update_Jacobi = directives.UpdatePreconditioner()
    
    # Options for outputting recovered models and predicted data for each beta.
    save_iteration = directives.SaveOutputDictEveryIteration(
        saveOnDisk=True, name=f"{key_invert}-smoother"
    )
    
    
    # Updating the preconditionner if it is model dependent.
    # update_jacobi = directives.UpdatePreconditioner()
    
    # Add sensitivity weights
    # sensitivity_weights = directives.UpdateSensitivityWeights()
    
    target_misfit = directives.TargetMisfit()
    
    # The directives are defined as a list.
    directives_list = [
        # sensitivity_weights,
        # update_jacobi,
        starting_beta,
        cool_beta,
        save_iteration,
        target_misfit,
    ]
    
    # Here we combine the inverse problem and the set of directives
    inv = inversion.BaseInversion(inv_prob, directives_list)
    return inv

# %%
inv = create_inversion("target_0")

# %%
inv.invProb.reg.multipliers
# Out:
# [0.025, 1.0, 0.0, 1.0, 0.0]

# %%
m0 = np.log(1./rho_back) * np.ones((mesh_2d.cell_centers[:, 1] < 0).sum())

# %%
len(m0)
# Out:
# 560

# %%
# %%time
inv.run(m0)
# Out:
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                         simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                         ***Done using same Solver, and solver_opts as the Simulation3DElectricField problem***
# /home/lheagy/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/direct/pardiso.py:49: PardisoTypeConversionWarning: Converting csc_matrix matrix to CSR format.
#   self.solver = MKLPardisoSolver(
# /home/lheagy/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:415: FutureWarning: In Future pymatsolver v0.4.0, passing a vector of shape (n, 1) to the solve method will return an array with shape (n, 1), instead of always returning a flattened array. This is to be consistent with numpy.linalg.solve broadcasting.
#   return self.solve(val)
# simpeg.SaveOutputDictEveryIteration will save your inversion progress as dictionary: '###-target_0-smoother-2025-06-21-14-57.npz'
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.51e-01  1.11e+04  0.00e+00  1.11e+04    9.59e+02      0
#    1  1.01e-01  6.95e+03  7.99e+03  7.76e+03    3.06e+03      0
#    2  6.71e-02  2.86e+03  5.81e+03  3.25e+03    2.16e+03      0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/utils/counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/inversion.py:113, in BaseInversion.run(self, m0)
#     111 self.directiveList.call("initialize")
#     112 print("model has any nan: {:b}".format(np.any(np.isnan(self.invProb.model))))
# --> 113 self.m = self.opt.minimize(self.invProb.evalFunction, self.invProb.model)
#     114 self.directiveList.call("finish")
#     116 return self.m
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/utils/counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/optimization.py:400, in Minimize.minimize(self, evalFunction, x0)
#     398 if self.stoppingCriteria():
#     399     break
# --> 400 self.searchDirection = self.findSearchDirection()
#     401 del (
#     402     self.H
#     403 )  #: Doing this saves memory, as it is not needed in the rest of the computations.
#     404 p = self.scaleSearchDirection(self.searchDirection)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/utils/counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/optimization.py:1093, in InexactGaussNewton.findSearchDirection(self)
#    1091 inp = {tol_key: self.tolCG, "maxiter": self.maxIterCG}
#    1092 Hinv = SolverCG(self.H, M=self.approxHinv, **inp)
# -> 1093 p = Hinv * (-self.g)
#    1094 return p
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:409, in Base.__mul__(self, val)
#     408 def __mul__(self, val):
# --> 409     return self.__matmul__(val)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:415, in Base.__matmul__(self, val)
#     414 def __matmul__(self, val):
# --> 415     return self.solve(val)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:342, in Base.solve(self, rhs)
#     340     if self._is_conjugate:
#     341         rhs = rhs.conjugate()
# --> 342     x = self._solve_single(rhs)
#     343 else:
#     344     if ndim == 2 and rhs.shape[-1] == 1:
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/wrappers.py:209, in wrap_iterative.<locals>._solve_single(self, rhs)
#     207 def _solve_single(self, rhs):
# --> 209     out = fun(self.A, rhs, **self.kwargs)
#     210     if type(out) is tuple and len(out) == 2:
#     211         # We are dealing with scipy output with an info!
#     212         X = out[0]
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/scipy/sparse/linalg/_isolve/iterative.py:411, in cg(A, b, x0, rtol, atol, maxiter, M, callback)
#     408     p = np.empty_like(r)
#     409     p[:] = z[:]
# --> 411 q = matvec(p)
#     412 alpha = rho_cur / dotprod(p, q)
#     413 x += alpha*p
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/scipy/sparse/linalg/_interface.py:258, in LinearOperator.matvec(self, x)
#     255 if x.shape != (N,) and x.shape != (N,1):
#     256     raise ValueError('dimension mismatch')
# --> 258 y = self._matvec(x)
#     260 if isinstance(x, np.matrix):
#     261     y = asmatrix(y)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/scipy/sparse/linalg/_interface.py:613, in _CustomLinearOperator._matvec(self, x)
#     612 def _matvec(self, x):
# --> 613     return self.__matvec_impl(x)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/inverse_problem.py:353, in BaseInvProblem.evalFunction.<locals>.H_fun(v)
#     352 def H_fun(v):
# --> 353     phi_d2Deriv = self.dmisfit.deriv2(m, v, f=f)
#     354     phi_m2Deriv = self.reg.deriv2(m, v=v)
#     356     return phi_d2Deriv + self.beta * phi_m2Deriv
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/objective_function.py:491, in ComboObjectiveFunction.deriv2(self, m, v, f)
#     489     continue
#     490 if f is not None and objfct.has_fields:
# --> 491     objfct_H = objfct.deriv2(m, v, f=f[i])
#     492 else:
#     493     objfct_H = objfct.deriv2(m, v)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/utils/counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/data_misfit.py:339, in L2DataMisfit.deriv2(self, m, v, f)
#     335 if f is None:
#     336     f = self.simulation.fields(m)
#     338 return 2 * self.simulation.Jtvec_approx(
# --> 339     m, self.W * (self.W * self.simulation.Jvec_approx(m, v, f=f)), f=f
#     340 )
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/utils/counter_utils.py:136, in timeIt.<locals>.wrapper(self, *args, **kwargs)
#     134 if isinstance(counter, Counter):
#     135     counter.countTic(self.__class__.__name__ + "." + f.__name__)
# --> 136 out = f(self, *args, **kwargs)
#     137 if isinstance(counter, Counter):
#     138     counter.countToc(self.__class__.__name__ + "." + f.__name__)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/simulation.py:299, in BaseSimulation.Jvec_approx(self, m, v, f)
#     266 @timeIt
#     267 def Jvec_approx(self, m, v, f=None):
#     268     r"""Approximation of the Jacobian times a vector for the model provided.
#     269
#     270     The Jacobian defines the derivative of the predicted data vector with respect to the
#    (...)
#     297         Approximation of the Jacobian times a vector for the model provided.
#     298     """
# --> 299     return self.Jvec(m, v, f)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/simpeg/electromagnetics/time_domain/simulation.py:267, in BaseTDEMSimulation.Jvec(self, m, v, f)
#     265         # step in time and overwrite
#     266         if tInd != len(self.time_steps + 1):
# --> 267             dun_dm_v[:, i] = Adiaginv * (JRHS - Asubdiag * dun_dm_v[:, i])
#     269 Jv = []
#     270 for src in self.survey.source_list:
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:409, in Base.__mul__(self, val)
#     408 def __mul__(self, val):
# --> 409     return self.__matmul__(val)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:415, in Base.__matmul__(self, val)
#     414 def __matmul__(self, val):
# --> 415     return self.solve(val)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/solvers.py:342, in Base.solve(self, rhs)
#     340     if self._is_conjugate:
#     341         rhs = rhs.conjugate()
# --> 342     x = self._solve_single(rhs)
#     343 else:
#     344     if ndim == 2 and rhs.shape[-1] == 1:
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pymatsolver/direct/pardiso.py:110, in Pardiso._solve_multiple(self, rhs)
#     109 def _solve_multiple(self, rhs):
# --> 110     sol = self.solver.solve(rhs, transpose=self._transposed)
#     111     return sol
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/pydiso/mkl_solver.py:272, in MKLPardisoSolver.solve(self, b, x, transpose)
#     269 self._handle.set_iparm(11, 2 if transpose else 0)
#     271 phase = 33
# --> 272 error = self._handle.call_pardiso(phase, self._data, self._indptr, self._indices, b, x)
#     273 if error:
#     274     raise PardisoError("Solve step error, "+_err_messages[error])
#
# KeyboardInterrupt:
