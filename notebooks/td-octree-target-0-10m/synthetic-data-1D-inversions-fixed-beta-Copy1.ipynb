# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import time
import pickle

from concurrent.futures import ProcessPoolExecutor, as_completed

import discretize 
from simpeg.utils import mkvc, plot_1d_layer_model
from simpeg import (
    maps,
    Data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils,
)
from simpeg.electromagnetics import time_domain as tdem
from simpeg.utils.solver_utils import get_default_solver

from simpeg.meta import MultiprocessingMetaSimulation #DaskMetaSimulation

# %%
Solver = get_default_solver()
Solver
# Out:
# pymatsolver.direct.pardiso.Pardiso

# %% [markdown]
# # load data

# %%
n_times_invert = 20

# %%
rx_locs = np.load("rx_locs.npy")

# %%
def load_pre_file(filepath):
    """
    Load a GIF-style .pre file (TDoctree format).

    Parameters
    ----------
    filepath : str
        Path to the .pre-style data file

    Returns
    -------
    dict
        {
            "ignore": float or None,
            "n_trx": int,
            "transmitters": list of {
                "location": list of float,
                "n_recv": int,
                "n_time": int,
                "receivers": list of {
                    "loc": (x, y, z),
                    "time": float,
                    "data": list of float
                }
            }
        }
    """
    with open(filepath, "r") as f:
        lines = [line.strip() for line in f if line.strip()]

    i = 0
    ignore_value = None
    transmitters = []

    # Parse IGNORE line if present
    if lines[i].startswith("IGNORE"):
        ignore_value = float(lines[i].split()[1])
        i += 1

    # Parse number of transmitters
    if lines[i].startswith("N_TRX"):
        n_trx = int(lines[i].split()[1])
        i += 1
    else:
        raise ValueError("Missing N_TRX line")

    while i < len(lines):
        if lines[i].startswith("TRX_LOOP"):
            i += 1
            location = list(map(float, lines[i].split()))
            i += 1
            if not lines[i].startswith("N_RECV"):
                raise ValueError("Expected N_RECV")
            n_recv = int(lines[i].split()[1])
            i += 1
            if not lines[i].startswith("N_TIME"):
                raise ValueError("Expected N_TIME")
            n_time = int(lines[i].split()[1])
            i += 1

            receivers = []
            for _ in range(n_recv * n_time):
                parts = lines[i].split()
                x, y, z = map(float, parts[0:3])
                time = float(parts[3])
                data = list(map(float, parts[4:]))
                receivers.append({
                    "loc": (x, y, z),
                    "time": time,
                    "data": data
                })
                i += 1

            transmitters.append({
                "location": location,
                "n_recv": n_recv,
                "n_time": n_time,
                "receivers": receivers
            })
        else:
            i += 1  # Skip unknown or empty lines

    return {
        "ignore": ignore_value,
        "n_trx": len(transmitters),
        "transmitters": transmitters
    }

# %%
dobs = load_pre_file("dpred-fwd.txt")

# %%
rx_times = np.array([dobs["transmitters"][0]["receivers"][j]["time"] for j in range(len(dobs["transmitters"][0]["receivers"]))])

# %%
rx_times
# Out:
# array([0.0001    , 0.00011836, 0.00014008, 0.0001658 , 0.00019624,
#        0.00023226, 0.0002749 , 0.00032536, 0.00038509, 0.00045579,
#        0.00053946, 0.00063849, 0.0007557 , 0.00089443, 0.00105862,
#        0.00125296, 0.00148297, 0.00175521, 0.00207742, 0.00245878])

# %%
n_times_invert = len(rx_times)

# %% [markdown]
# # create survey

# %%
tx_height = rx_locs[0, 2]
source_list = []

for i in range(rx_locs.shape[0]): 
    rx = tdem.receivers.PointMagneticFluxTimeDerivative(rx_locs[i, :], rx_times, orientation="z")
    src = tdem.sources.CircularLoop(
        receiver_list=[rx], location=rx_locs[i, :], orientation="z", radius=10, 
        waveform=tdem.sources.StepOffWaveform()
    )
    source_list.append(src)

full_survey = tdem.Survey(source_list)

# %%
dobs_values = np.zeros((n_times_invert, len(dobs["transmitters"])))
for i in range(len(dobs["transmitters"])): 
    for j in range(n_times_invert): 
        dobs_values[j, i] = dobs["transmitters"][i]["receivers"][j]["data"][-1]

# %%
relative_error = 0.1
noise_floor = 1e-11
observed_data = Data(survey=full_survey, dobs=-discretize.utils.mkvc(dobs_values), relative_error=relative_error, noise_floor=noise_floor)

# %%
ind = 25
rx_locs[ind, :]
# Out:
# array([ 300., -200.,   30.])

# %%
ubc_mesh = discretize.TreeMesh.read_UBC("octree_mesh.txt")
model = discretize.TreeMesh.read_model_UBC(ubc_mesh, "target_0.con")

# %%
src_ind = 90

# %%
fig, ax = plt.subplots(1, 1)
plt.colorbar(
    ubc_mesh.plot_slice(
        model, ax=ax, pcolor_opts={"norm":LogNorm()}, 
        normal="Z", ind=1468
    )[0], 
    ax=ax
)

ax.set_xlim(1000*np.r_[-1, 1])
ax.set_ylim(1000*np.r_[-1, 1])

ax.plot(rx_locs[:, 0], rx_locs[:, 1], "wo", ms=4)
ax.plot(rx_locs[src_ind, 0], rx_locs[src_ind, 1], "rs", ms=6)

# %%
observed_data[src, src.receiver_list[0]]
# Out:
# array([-3.464468e-09, -2.325646e-09, -1.529475e-09, -1.052343e-09,
#        -7.139420e-10, -4.806080e-10, -3.221612e-10, -2.149543e-10,
#        -1.429087e-10, -9.180024e-11, -6.201548e-11, -4.162420e-11,
#        -2.768266e-11, -1.834065e-11, -1.197157e-11, -7.877901e-12,
#        -5.315422e-12, -3.547845e-12, -2.352372e-12, -1.552060e-12])

# %%
for src_ind in range(180): 
    src = full_survey.source_list[src_ind]
    
    # plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
    plt.loglog(rx_times, -observed_data[src, src.receiver_list[0]], "C0-o", ms=4, alpha=0.1)

# %%
thicknesses_true = np.r_[40, 40]
sigma_true = 1./np.r_[500, 20, 500]

# %%
src_ind = 90
source_sounding = full_survey.source_list[src_ind]
survey_sounding = tdem.Survey([source_sounding])
sim1d_true = tdem.Simulation1DLayered(
    survey=survey_sounding, thicknesses=thicknesses_true, sigmaMap=maps.IdentityMap(nP=3)
)

# %%
dpred_halfspace = sim1d_true.dpred(1./500*np.ones(3))

# %%
dpred_1d = sim1d_true.dpred(sigma_true)

# %%
fig, ax = plt.subplots(1, 1)

ax.loglog(rx_times, -dpred_halfspace, "k-o", ms=4, label="halfspace")
ax.loglog(rx_times, -observed_data[source_sounding, source_sounding.receiver_list[0]], "C0-o", ms=4, label="dobs")
ax.loglog(rx_times, -dpred_1d, "C1-o", ms=4, label="1D")

ax.legend()

# %%
# octree_mesh = discretize.load_mesh("./synthetic-data/treemesh.json")

# octree_mesh = discretize.load_mesh()

# %%
cs = 5
core_region = 200
npad = 20
padding_factor = 1.3

thicknesses1d = discretize.utils.unpack_widths(
    [(cs, np.int64(np.ceil(core_region/cs))), (cs, npad, padding_factor)]
)

# %%
np.sum(thicknesses1d)
# Out:
# np.float64(4296.075484557508)

# %%
# set up 1D inversion 
def create_inversion(
    ind,
    relative_error=0.1,
    noise_floor=1e-11,
    alpha_s = 1e-3,
    alpha_x = 1,
    rho_back = 500,
    beta0 = 5,
): 
    
    rx_times_invert = rx_times[:n_times_invert]
    
    # def create inv
    # src = full_survey.source_list[ind]
    # rx = src.receiver_list[0]
    
    rx_sounding = tdem.receivers.PointMagneticFluxTimeDerivative(
        locations=rx_locs[ind, :], times=rx_times_invert, orientation="z"
    )
    src_sounding = tdem.sources.CircularLoop(
        receiver_list=[rx_sounding], location=rx_locs[ind, :], orientation="z", 
        radius=10, 
        waveform=tdem.sources.StepOffWaveform()
    )
    survey_sounding = tdem.Survey([src_sounding])
    mesh_invert = discretize.TensorMesh([(np.r_[thicknesses1d, thicknesses1d[-1]])], origin="0")
    
    sim1d = tdem.Simulation1DLayered(
        survey=survey_sounding, thicknesses=thicknesses1d, sigmaMap=maps.ExpMap(mesh_invert)
    )

    source_sounding = full_survey.source_list[ind]
    data_invert = Data(
        survey_sounding, 
        dobs=observed_data[source_sounding, source_sounding.receiver_list[0]],
        relative_error=relative_error,
        noise_floor=noise_floor
    )
    
    dmis = data_misfit.L2DataMisfit(simulation=sim1d, data=data_invert)
    reg = regularization.WeightedLeastSquares(
        mesh_invert, alpha_s=alpha_s, alpha_x=alpha_x, 
        # reference_model=np.log(1./rho_back),
        # norms=norms
    )
    
    opt = optimization.InexactGaussNewton(maxIter=10)
    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=beta0)
    
    # Defining a starting value for the trade-off parameter (beta) between the data
    # misfit and the regularization.
    starting_beta = directives.BetaEstimate_ByEig(beta0_ratio=10)
    
    cool_beta = directives.BetaSchedule(coolingFactor=1.5, coolingRate=1)
    
    # Update the preconditionner
    update_Jacobi = directives.UpdatePreconditioner()
    
    # Options for outputting recovered models and predicted data for each beta.
    save_iteration = directives.SaveOutputDictEveryIteration(
        saveOnDisk=False, name=f"inv-dict-{rx.locations[0,0]}"
    )
    
    
    # Updating the preconditionner if it is model dependent.
    update_jacobi = directives.UpdatePreconditioner()
    
    # Add sensitivity weights
    sensitivity_weights = directives.UpdateSensitivityWeights()
    
    target_misfit = directives.TargetMisfit()
    
    # The directives are defined as a list.
    directives_list = [
        # sensitivity_weights,
        # update_jacobi,
        starting_beta,
        cool_beta,
        save_iteration,
        target_misfit,
    ]
    
    # Here we combine the inverse problem and the set of directives
    inv = inversion.BaseInversion(inv_prob, directives_list)
    return inv

# %%
ind = 90
inv = create_inversion(ind)

# %%
rho_start = 500
m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
mopt = inv.run(m0)
# Out:
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  6.02e+01  5.91e+02  0.00e+00  5.91e+02    6.89e+01      0
#    1  4.01e+01  3.28e+02  7.47e-02  3.31e+02    1.02e+02      2
#    2  2.67e+01  1.59e+02  2.23e-01  1.65e+02    7.24e+01      2
#    3  1.78e+01  1.06e+02  3.53e-01  1.12e+02    5.77e+01      2
#    4  1.19e+01  8.73e+01  5.23e-01  9.36e+01    1.56e+02      2
#    5  7.93e+00  7.49e+01  5.26e-01  7.91e+01    1.45e+01      0
#    6  5.28e+00  5.92e+01  7.88e-01  6.34e+01    1.20e+02      2
#    7  3.52e+00  4.87e+01  1.13e+00  5.26e+01    1.67e+02      2   Skip BFGS
#    8  2.35e+00  4.42e+01  2.08e+00  4.90e+01    3.05e+02      1   Skip BFGS
#    9  1.57e+00  2.40e+01  2.49e+00  2.79e+01    5.86e+00      0
#   10  1.04e+00  2.25e+01  2.54e+00  2.52e+01    3.63e+01      3
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.7730e+00 <= tolF*(1+|f0|) = 5.9226e+01
# 1 : |xc-x_last| = 7.4097e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 3.6252e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.6252e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------

# %%
iterations = len(inv.directiveList.dList[-2].outDict)

# %%
# plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
# plt.loglog(rx_times, -data_dict[key][src, rx], "C0o", ms=4)
rx_times_invert = rx_times[:n_times_invert]
plt.errorbar(rx_times_invert, -inv.invProb.dmisfit[0][1].data.dobs, yerr=inv.invProb.dmisfit[0][1].data.standard_deviation)
plt.loglog(rx_times_invert, -inv.directiveList.dList[-2].outDict[iterations]["dpred"], "C1-s", ms=4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(2, 4))
plot_1d_layer_model(
    thicknesses1d, np.exp(mopt), ax=ax, color="C0", label="recovered"
)
plot_1d_layer_model(
    thicknesses_true, sigma_true, ax=ax, color="k", label="true"
)
ax.set_ylim([450, 0])
ax.set_xlim([1e-4, 1e-1])
# Out:
# (0.0001, 0.1)

# %%
# directory = "./synthetic-invs-1d-fixed-beta"

# %%
# def run_inv(key, ind, dobs): 
#     inv = create_inversion(key, ind, dobs)
#     rho_start = 500
#     m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
    
#     label_key=f"{key}_{ind}"
    
#     mopt = inv.run(m0)
#     np.save(f"{directory}/{label_key}_model.npy", mopt)
    
#     inv_dict = inv.directiveList.dList[-2].outDict
#     with open(f"{directory}/{label_key}_inv_dict.pkl", "wb") as f:
#         pickle.dump(inv_dict, f)

#     return label_key, mopt

# %%
# key = "target_0"
# n_times_invert = 20
# ind = 25
# src = full_survey.source_list[ind]
# rx = src.receiver_list[0]
# dobs = data_dict[key][src, rx][:n_times_invert]

# inv = create_inversion(key, ind, dobs)

# %%
# rho_start = 500
# m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
# mopt = inv.run(m0)

# %%
# rho_back = 500
# sigma_back = 1./rho_back 

# rho_target = 20
# sigma_target = 1./rho_target
# target_z_center = -60
# target_thickness = 40

# model_true = np.log(1/np.r_[rho_back, rho_target, rho_back])

# thicknesses_true = np.r_[-target_z_center - target_thickness/2, target_thickness]

# %%
model_keys = list(data_dict.keys())[1:]
model_keys
# Out:
# ['target_30', 'target_45', 'target_0', 'target_15']

# %%
rx_locs.shape
# Out:
# (51, 3)

# %%
inv_dict = {}
n_times_invert = 20

# key = model_keys[0]
with ProcessPoolExecutor() as executor:
    futures = []
    for key in model_keys: 
        for ind in range(rx_locs.shape[0]): 
            src = full_survey.source_list[ind]
            rx = src.receiver_list[0]
            dobs = data_dict[key][src, rx][:n_times_invert]
            futures.append(
                executor.submit(run_inv, key, ind, dobs)
            )
            
    for future in as_completed(futures):
        label_key, mopt = future.result()
        inv_dict[label_key] = mopt
# Out:
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
#
#
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
#
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# Running inversion with SimPEG v0.24.0
#
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# Running inversion with SimPEG v0.24.0
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================model has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0model has any nan: 0
#
#
# ============================ Inexact Gauss Newton ============================-----------------------------------------------------------------------------
# ============================ Inexact Gauss Newton ============================
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0============================ Inexact Gauss Newton ============================x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
#
#
#
#
# ============================ Inexact Gauss Newton ============================x0 has any nan: 0
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
# model has any nan: 0x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
#
#
# x0 has any nan: 0
# x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
#
# ============================ Inexact Gauss Newton ============================
# model has any nan: 0
#
# x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# model has any nan: 0============================ Inexact Gauss Newton ============================
# model has any nan: 0
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# ============================ Inexact Gauss Newton ============================
# model has any nan: 0============================ Inexact Gauss Newton ============================
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================x0 has any nan: 0-----------------------------------------------------------------------------model has any nan: 0
#
#
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# model has any nan: 0
# model has any nan: 0model has any nan: 0
#
# model has any nan: 0============================ Inexact Gauss Newton ============================
# x0 has any nan: 0model has any nan: 0
# -----------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================
#
# model has any nan: 0
# model has any nan: 0x0 has any nan: 0
# model has any nan: 0
#
# ============================ Inexact Gauss Newton ============================
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0
# -----------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
#
#
# ============================ Inexact Gauss Newton ============================model has any nan: 0
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================-----------------------------------------------------------------------------
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# x0 has any nan: 0-----------------------------------------------------------------------------
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
#
#
#
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# model has any nan: 0-----------------------------------------------------------------------------x0 has any nan: 0============================ Inexact Gauss Newton ============================model has any nan: 0
# x0 has any nan: 0-----------------------------------------------------------------------------model has any nan: 0-----------------------------------------------------------------------------
#
#
#
# ============================ Inexact Gauss Newton ============================
#
# x0 has any nan: 0
# -----------------------------------------------------------------------------============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
# -----------------------------------------------------------------------------
#
# x0 has any nan: 0x0 has any nan: 0x0 has any nan: 0
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
#
#
#
# -----------------------------------------------------------------------------x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------
# model has any nan: 0
#
#
#
# -----------------------------------------------------------------------------x0 has any nan: 0x0 has any nan: 0
#
# ============================ Inexact Gauss Newton ============================
#
#
# ============================ Inexact Gauss Newton ============================x0 has any nan: 0
#
#
# model has any nan: 0model has any nan: 0
# model has any nan: 0
#
# ============================ Inexact Gauss Newton ============================
# model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0x0 has any nan: 0============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
# -----------------------------------------------------------------------------
#
#
#
# ============================ Inexact Gauss Newton ============================
# model has any nan: 0============================ Inexact Gauss Newton ============================model has any nan: 0
# x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
#
#
# model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0model has any nan: 0============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------model has any nan: 0
#
#
#
# model has any nan: 0x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------
# model has any nan: 0============================ Inexact Gauss Newton ============================model has any nan: 0
# model has any nan: 0
#
#
# ============================ Inexact Gauss Newton ============================
#
#
#
# model has any nan: 0
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------x0 has any nan: 0-----------------------------------------------------------------------------
#
# ============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================model has any nan: 0-----------------------------------------------------------------------------
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0============================ Inexact Gauss Newton ============================
# model has any nan: 0model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================
#
#
# ============================ Inexact Gauss Newton ============================
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================
#
#
#
#
#
# ============================ Inexact Gauss Newton ============================
#
# ============================ Inexact Gauss Newton ============================
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0============================ Inexact Gauss Newton ============================----------------------------------------------------------------------------------------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# x0 has any nan: 0
#
#
#
#
#
#
# x0 has any nan: 0
#
# x0 has any nan: 0x0 has any nan: 0
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
#
# -----------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# x0 has any nan: 0
#
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------x0 has any nan: 0
#
#
# x0 has any nan: 0x0 has any nan: 0
# x0 has any nan: 0
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================x0 has any nan: 0
#
#
#
#
# x0 has any nan: 0x0 has any nan: 0
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# x0 has any nan: 0
# x0 has any nan: 0
#
#
# x0 has any nan: 0x0 has any nan: 0
# x0 has any nan: 0
#
# -----------------------------------------------------------------------------
#
# x0 has any nan: 0
#    0  5.00e+00  3.42e+02  0.00e+00  3.42e+02    1.11e+02      0
#    0  5.00e+00  4.28e+02  0.00e+00  4.28e+02    1.10e+02      0
#    0  5.00e+00  2.69e+02  0.00e+00  2.69e+02    1.09e+02      0
#    0  5.00e+00  3.31e+02  0.00e+00  3.31e+02    1.13e+02      0
#    0  5.00e+00  7.47e+02  0.00e+00  7.47e+02    8.24e+01      0
#    0  5.00e+00  5.87e+02  0.00e+00  5.87e+02    9.97e+01      0
#    0  5.00e+00  3.79e+02  0.00e+00  3.79e+02    1.12e+02      0                 0  5.00e+00  2.08e+02  0.00e+00  2.08e+02    1.07e+02      0
#
#    0  5.00e+00  1.02e+02  0.00e+00  1.02e+02    7.94e+01      0                 0  5.00e+00  7.14e+01  0.00e+00  7.14e+01    7.50e+01      0                 0  5.00e+00  8.71e+01  0.00e+00  8.71e+01    7.44e+01      0
#    0  5.00e+00  8.81e+02  0.00e+00  8.81e+02    6.28e+01      0
#    0  5.00e+00  1.23e+02  0.00e+00  1.23e+02    9.21e+01      0
#    0  5.00e+00  2.09e+02  0.00e+00  2.09e+02    1.03e+02      0
#
#
#    0  5.00e+00  6.30e+01  0.00e+00  6.30e+01    6.50e+01      0                 0  5.00e+00  2.38e+02  0.00e+00  2.38e+02    1.06e+02      0                 0  5.00e+00  2.45e+02  0.00e+00  2.45e+02    1.10e+02      0
#    0  5.00e+00  1.38e+02  0.00e+00  1.38e+02    8.95e+01      0
#
#    0  5.00e+00  4.29e+02  0.00e+00  4.29e+02    1.10e+02      0                 0  5.00e+00  6.28e+02  0.00e+00  6.28e+02    9.07e+01      0
#
#
#    0  5.00e+00  1.83e+02  0.00e+00  1.83e+02    9.88e+01      0                 0  5.00e+00  5.18e+02  0.00e+00  5.18e+02    1.05e+02      0                 0  5.00e+00  6.43e+02  0.00e+00  6.43e+02    9.43e+01      0
#
#
#    0  5.00e+00  3.83e+02  0.00e+00  3.83e+02    1.11e+02      0                 0  5.00e+00  5.75e+02  0.00e+00  5.75e+02    9.89e+01      0                 0  5.00e+00  8.88e+02  0.00e+00  8.88e+02    6.07e+01      0
#
#    0  5.00e+00  6.97e+02  0.00e+00  6.97e+02    8.84e+01      0                 0  5.00e+00  8.50e+02  0.00e+00  8.50e+02    6.28e+01      0
#
#    0  5.00e+00  8.79e+02  0.00e+00  8.79e+02    6.05e+01      0                 0  5.00e+00  8.61e+02  0.00e+00  8.61e+02    6.64e+01      0
#    0  5.00e+00  4.76e+02  0.00e+00  4.76e+02    1.08e+02      0                 0  5.00e+00  2.87e+02  0.00e+00  2.87e+02    1.12e+02      0
#
#
#    0  5.00e+00  7.41e+01  0.00e+00  7.41e+01    6.95e+01      0
#    0  5.00e+00  7.15e+02  0.00e+00  7.15e+02    7.87e+01      0
#    0  5.00e+00  1.19e+02  0.00e+00  1.19e+02    8.45e+01      0
#    0  5.00e+00  5.48e+02  0.00e+00  5.48e+02    1.03e+02      0                 0  5.00e+00  7.92e+02  0.00e+00  7.92e+02    7.65e+01      0
#
#    0  5.00e+00  1.47e+02  0.00e+00  1.47e+02    9.76e+01      0
#
#    0  5.00e+00  8.31e+02  0.00e+00  8.31e+02    7.11e+01      0                 0  5.00e+00  1.59e+02  0.00e+00  1.59e+02    9.43e+01      0
#    0  5.00e+00  4.79e+02  0.00e+00  4.79e+02    1.08e+02      0
#
#    0  5.00e+00  1.03e+02  0.00e+00  1.03e+02    8.64e+01      0                 0  5.00e+00  8.56e+01  0.00e+00  8.56e+01    8.06e+01      0
#
#    0  5.00e+00  5.61e+02  0.00e+00  5.61e+02    1.02e+02      0                 0  5.00e+00  1.76e+02  0.00e+00  1.76e+02    1.03e+02      0
#
#    0  5.00e+00  7.95e+02  0.00e+00  7.95e+02    6.87e+01      0                 0  5.00e+00  5.32e+02  0.00e+00  5.32e+02    1.04e+02      0
#
#    0  5.00e+00  3.04e+02  0.00e+00  3.04e+02    1.10e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.7047e+01
# 0 : |xc-x_last| = 4.9757e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.0860e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0860e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# ------------------------- STOP! -------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.2391e+00------------------------- STOP! -------------------------
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0944e+01
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0292e+01------------------------- STOP! -------------------------------------------------- STOP! -------------------------
# 1 : |xc-x_last| = 3.9241e+00 <= tolX*(1+|x0|) = 4.9538e+00simpeg.InvProblem will set Regularization.reference_model to m0.
# 1 : |xc-x_last| = 2.2793e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
#
# 1 : |xc-x_last| = 2.9717e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : |proj(x-g)-x|    = 7.5037e+01 <= tolG          = 1.0000e-01
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2419e+01------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.8064e+000 : |proj(x-g)-x|    = 1.0683e+02 <= tolG          = 1.0000e-01
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
# 0 : |proj(x-g)-x|    = 7.9391e+01 <= tolG          = 1.0000e-01
# 1 : |xc-x_last| = 2.9884e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.1034e+011 : |xc-x_last| = 2.7328e+00 <= tolX*(1+|x0|) = 4.9538e+000 : |proj(x-g)-x|    = 7.5037e+01 <= 1e3*eps       = 1.0000e-02
#
# 0 : |proj(x-g)-x|    = 7.9391e+01 <= 1e3*eps       = 1.0000e-02
# ------------------------- STOP! -------------------------
#
#
# 0 : maxIter   =      10    <= iter          =      1
# 0 : |proj(x-g)-x|    = 1.0683e+02 <= 1e3*eps       = 1.0000e-021 : |xc-x_last| = 4.3789e+00 <= tolX*(1+|x0|) = 4.9538e+000 : |proj(x-g)-x|    = 9.2148e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.4374e+01 <= tolG          = 1.0000e-01
#
#
#
# 0 : maxIter   =      10    <= iter          =      1
# 0 : |proj(x-g)-x|    = 9.2148e+01 <= 1e3*eps       = 1.0000e-020 : maxIter   =      10    <= iter          =      11 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3897e+01------------------------- DONE! -------------------------
# 0 : |proj(x-g)-x|    = 7.4374e+01 <= 1e3*eps       = 1.0000e-02
#
# 0 : |proj(x-g)-x|    = 1.0269e+02 <= tolG          = 1.0000e-01
#
# ------------------------- DONE! -------------------------
# 0 : maxIter   =      10    <= iter          =      10 : maxIter   =      10    <= iter          =      1
#
# ------------------------- DONE! -------------------------
#
#
# 1 : |xc-x_last| = 3.4657e+00 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- DONE! -------------------------
#
# ------------------------- DONE! -------------------------
#
#
# 0 : |proj(x-g)-x|    = 1.0269e+02 <= 1e3*eps       = 1.0000e-02simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
# 0 : |proj(x-g)-x|    = 8.9504e+01 <= tolG          = 1.0000e-01simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# ------------------------- STOP! -------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# 0 : maxIter   =      10    <= iter          =      10 : |proj(x-g)-x|    = 8.9504e+01 <= 1e3*eps       = 1.0000e-02simpeg.InvProblem will set Regularization.reference_model to m0.
# ------------------------- STOP! -------------------------
# ------------------------- STOP! -------------------------
# ------------------------- DONE! -------------------------
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4646e+01simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.3905e+01------------------------- STOP! -------------------------0 : maxIter   =      10    <= iter          =      1
#
#
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.3969e+00
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# ------------------------- DONE! -------------------------
#
# ------------------------- STOP! -------------------------simpeg.InvProblem will set Regularization.reference_model to m0.1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.6583e+00
#
#
#
# 1 : |xc-x_last| = 4.6657e+00 <= tolX*(1+|x0|) = 4.9538e+00simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.------------------------- STOP! -------------------------------------------------- STOP! -------------------------
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
# 1 : |xc-x_last| = 2.2784e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 1 : |xc-x_last| = 4.3202e+00 <= tolX*(1+|x0|) = 4.9538e+00simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0371e+01simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# ------------------------- STOP! -------------------------
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
# 1 : |xc-x_last| = 2.4977e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7677e+011 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.8414e+010 : |proj(x-g)-x|    = 1.0999e+02 <= tolG          = 1.0000e-01
# ------------------------- STOP! -------------------------
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
# 0 : |proj(x-g)-x|    = 1.0600e+02 <= tolG          = 1.0000e-011 : |xc-x_last| = 2.7334e+00 <= tolX*(1+|x0|) = 4.9538e+000 : |proj(x-g)-x|    = 8.0623e+01 <= tolG          = 1.0000e-011 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.4843e+01
#
#
#
# 0 : |proj(x-g)-x|    = 8.6394e+01 <= tolG          = 1.0000e-01
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# 1 : |xc-x_last| = 3.5761e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 6.4967e+01 <= tolG          = 1.0000e-01
# ------------------------- STOP! -------------------------   1  5.00e+00  2.19e+01  9.74e+00  7.06e+01    6.74e+01      0
# 0 : |proj(x-g)-x|    = 1.0600e+02 <= 1e3*eps       = 1.0000e-02simpeg.InvProblem will set Regularization.reference_model to m0.------------------------- STOP! -------------------------
#
#
# 1 : |xc-x_last| = 4.1083e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 8.0623e+01 <= 1e3*eps       = 1.0000e-02
#
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6037e+01
#
# 0 : |proj(x-g)-x|    = 6.4967e+01 <= 1e3*eps       = 1.0000e-021 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.5131e+00------------------------- STOP! -------------------------
# 0 : maxIter   =      10    <= iter          =      10 : |proj(x-g)-x|    = 1.0999e+02 <= 1e3*eps       = 1.0000e-02
#
# 0 : |proj(x-g)-x|    = 8.4480e+01 <= tolG          = 1.0000e-01simpeg.InvProblem will set Regularization.reference_model to m0.1 : |xc-x_last| = 3.2671e+00 <= tolX*(1+|x0|) = 4.9538e+00simpeg.InvProblem will set Regularization.reference_model to m0.
# 0 : maxIter   =      10    <= iter          =      1
# 0 : |proj(x-g)-x|    = 8.6394e+01 <= 1e3*eps       = 1.0000e-02
#
#
#
#
# 0 : |proj(x-g)-x|    = 9.8755e+01 <= tolG          = 1.0000e-01
#
# 1 : |xc-x_last| = 2.5010e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1985e+010 : maxIter   =      10    <= iter          =      1
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
# 0 : maxIter   =      10    <= iter          =      11 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.0486e+01
#
# 0 : |proj(x-g)-x|    = 9.7649e+01 <= tolG          = 1.0000e-01------------------------- DONE! -------------------------0 : maxIter   =      10    <= iter          =      1
#
# 0 : |proj(x-g)-x|    = 6.9538e+01 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 9.8755e+01 <= 1e3*eps       = 1.0000e-021 : |xc-x_last| = 3.8485e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# 0 : maxIter   =      10    <= iter          =      1
#
# 1 : |xc-x_last| = 3.2163e+00 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- DONE! -------------------------
# ------------------------- DONE! -------------------------
#
#
# 0 : |proj(x-g)-x|    = 6.9538e+01 <= 1e3*eps       = 1.0000e-02
#
# 0 : |proj(x-g)-x|    = 9.4313e+01 <= tolG          = 1.0000e-01------------------------- DONE! -------------------------0 : |proj(x-g)-x|    = 9.7649e+01 <= 1e3*eps       = 1.0000e-02
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# 0 : |xc-x_last| = 5.3171e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 8.4480e+01 <= 1e3*eps       = 1.0000e-02
# 0 : |proj(x-g)-x|    = 1.0263e+02 <= tolG          = 1.0000e-01
#
# ------------------------- DONE! -------------------------0 : maxIter   =      10    <= iter          =      1------------------------- DONE! -------------------------
# Running inversion with SimPEG v0.24.0
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# 0 : |proj(x-g)-x|    = 9.4313e+01 <= 1e3*eps       = 1.0000e-02
#
#
# ------------------------- DONE! -------------------------
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# 0 : maxIter   =      10    <= iter          =      10 : |proj(x-g)-x|    = 1.1040e+02 <= tolG          = 1.0000e-01
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#    1  5.00e+00  3.67e+01  9.57e+00  8.46e+01    1.10e+02      0
#
#
# ...
#    4  5.00e+00  3.03e+01  2.89e+01  1.75e+02    1.94e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1212e+02
# 1 : |xc-x_last| = 4.2669e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.7796e+02 <= tolG          = 1.0000e-01
#    5  5.00e+00  2.85e+01  3.37e+01  1.97e+02    1.68e+01      0   Skip BFGS  0 : |proj(x-g)-x|    = 2.7796e+02 <= 1e3*eps       = 1.0000e-02
#
# 0 : maxIter   =      10    <= iter          =      5
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1696e+02
#    5  5.00e+00  2.50e+01  3.45e+01  1.97e+02    2.84e+01      0   Skip BFGS  1 : |xc-x_last| = 3.4063e-01 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : |proj(x-g)-x|    = 1.9321e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9321e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      6
# ------------------------- DONE! -------------------------
#    5  5.00e+00  2.19e+01  3.24e+01  1.84e+02    4.80e+01      0
#    6  5.00e+00  3.06e+01  3.20e+01  1.91e+02    5.99e+01      1   Skip BFGS     5  5.00e+00  2.33e+01  3.46e+01  1.96e+02    5.95e+01      0   Skip BFGS
#
#    5  5.00e+00  2.98e+01  2.23e+01  1.42e+02    3.41e+02      0   Skip BFGS
#    5  5.00e+00  2.69e+01  3.17e+01  1.85e+02    1.60e+01      0
#    4  5.00e+00  2.34e+01  2.46e+01  1.46e+02    2.75e+01      0                 5  5.00e+00  2.76e+01  2.99e+01  1.77e+02    1.51e+01      0
#
#    4  5.00e+00  2.93e+01  2.68e+01  1.63e+02    1.95e+01      0
#   10  5.00e+00  3.59e+01  3.38e+01  2.05e+02    2.64e+02      2   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.8963e+00 <= tolF*(1+|f0|) = 1.2760e+02
# 1 : |xc-x_last| = 4.9928e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.6361e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6361e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    6  5.00e+00  3.18e+01  3.43e+01  2.03e+02    1.15e+02      1
#    6  5.00e+00  3.59e+01  3.76e+01  2.24e+02    1.66e+02      0   Skip BFGS
#    4  5.00e+00  2.06e+01  2.27e+01  1.34e+02    2.46e+01      0
#    6  5.00e+00  3.82e+01  3.27e+01  2.02e+02    2.08e+02      0   Skip BFGS
#    6  5.00e+00  2.12e+01  3.52e+01  1.97e+02    1.02e+02      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0191e+02
# 1 : |xc-x_last| = 2.2226e-01 <= tolX*(1+|x0|) = 4.9538e+00
#    6  5.00e+00  4.25e+01  3.15e+01  2.00e+02    2.07e+02      0   Skip BFGS  0 : |proj(x-g)-x|    = 3.4124e+02 <= tolG          = 1.0000e-01
#
# 0 : |proj(x-g)-x|    = 3.4124e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      6
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.7346e+01
# 1 : |xc-x_last| = 2.2259e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.7537e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7537e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      5
# ------------------------- DONE! -------------------------
#    6  5.00e+00  2.86e+01  3.51e+01  2.04e+02    1.41e+02      1   Skip BFGS
#    5  5.00e+00  2.78e+01  2.78e+01  1.67e+02    1.58e+01      0
#    6  5.00e+00  3.06e+01  3.42e+01  2.02e+02    1.48e+02      1   Skip BFGS
#    6  5.00e+00  2.54e+01  3.27e+01  1.89e+02    1.86e+01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.3055e+01
# 1 : |xc-x_last| = 2.1018e+00 <= tolX*(1+|x0|) = 4.9538e+00  10  5.00e+00  2.52e+01  2.43e+01  1.47e+02    1.35e+02      1   Skip BFGS
#
# 0 : |proj(x-g)-x|    = 2.4598e+01 <= tolG          = 1.0000e-01------------------------- STOP! -------------------------
#
# 0 : |proj(x-g)-x|    = 2.4598e+01 <= 1e3*eps       = 1.0000e-021 : |fc-fOld| = 5.7088e+00 <= tolF*(1+|f0|) = 1.1098e+02
# 0 : maxIter   =      10    <= iter          =      5
#    6  5.00e+00  2.27e+01  3.22e+01  1.84e+02    5.36e+01      0   Skip BFGS
# 1 : |xc-x_last| = 8.1837e-01 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- DONE! -------------------------
#
# 0 : |proj(x-g)-x|    = 1.3509e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.3509e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1520e+02
# 1 : |xc-x_last| = 3.2470e-01 <= tolX*(1+|x0|) = 4.9538e+00
#    6  5.00e+00  2.41e+01  2.98e+01  1.73e+02    3.65e+01      0   Skip BFGS  0 : |proj(x-g)-x|    = 2.0752e+02 <= tolG          = 1.0000e-01
#
# 0 : |proj(x-g)-x|    = 2.0752e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      7
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1312e+02
# 1 : |xc-x_last| = 3.5803e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.0699e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.0699e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      7
# ------------------------- DONE! -------------------------
#    6  5.00e+00  3.10e+01  3.08e+01  1.85e+02    1.34e+02      0   Skip BFGS
#    6  5.00e+00  2.64e+01  2.90e+01  1.71e+02    1.96e+01      0   Skip BFGS
#    6  5.00e+00  2.48e+01  3.08e+01  1.79e+02    1.98e+01      0   Skip BFGS
#    5  5.00e+00  2.70e+01  2.57e+01  1.56e+02    1.61e+01      0
#    7  5.00e+00  2.92e+01  3.49e+01  2.04e+02    1.47e+02      0
#    7  5.00e+00  3.06e+01  3.08e+01  1.84e+02    9.79e+01      1   Skip BFGS
#    7  5.00e+00  3.99e+01  3.21e+01  2.00e+02    2.44e+02      0   Skip BFGS
#    7  5.00e+00  3.46e+01  3.19e+01  1.94e+02    1.73e+02      1   Skip BFGS
#    6  5.00e+00  2.72e+01  2.68e+01  1.61e+02    2.19e+01      0   Skip BFGS
#    7  5.00e+00  2.28e+01  3.13e+01  1.79e+02    3.00e+01      0
#    7  5.00e+00  3.37e+01  2.87e+01  1.77e+02    1.59e+02      0   Skip BFGS
#    7  5.00e+00  2.61e+01  2.84e+01  1.68e+02    5.95e+01      0   Skip BFGS
#    7  5.00e+00  2.12e+01  3.28e+01  1.85e+02    1.22e+02      1   Skip BFGS
#    7  5.00e+00  2.86e+01  3.23e+01  1.90e+02    1.57e+02      1   Skip BFGS
#    7  5.00e+00  2.36e+01  2.98e+01  1.73e+02    2.38e+01      0   Skip BFGS
#    7  5.00e+00  2.60e+01  2.79e+01  1.66e+02    2.59e+01      0   Skip BFGS
#    6  5.00e+00  2.67e+01  2.47e+01  1.50e+02    2.45e+01      0   Skip BFGS
#    7  5.00e+00  2.83e+01  2.78e+01  1.68e+02    1.35e+02      1   Skip BFGS
#    8  5.00e+00  2.01e+01  3.08e+01  1.74e+02    3.44e+01      0
#    8  5.00e+00  2.74e+01  3.15e+01  1.85e+02    1.73e+02      1   Skip BFGS
#    8  5.00e+00  2.51e+01  2.90e+01  1.70e+02    8.47e+01      0
#    8  5.00e+00  3.08e+01  2.94e+01  1.78e+02    1.28e+02      1   Skip BFGS
#    8  5.00e+00  2.04e+01  2.69e+01  1.55e+02    1.69e+01      0
#    7  5.00e+00  2.76e+01  2.57e+01  1.56e+02    3.24e+01      0   Skip BFGS
#    8  5.00e+00  3.69e+01  3.01e+01  1.88e+02    2.23e+02      1   Skip BFGS
#    8  5.00e+00  2.38e+01  2.86e+01  1.67e+02    3.33e+01      0   Skip BFGS
#    8  5.00e+00  2.82e+01  2.65e+01  1.61e+02    5.23e+01      0   Skip BFGS
#    8  5.00e+00  2.64e+01  2.76e+01  1.64e+02    7.90e+01      1   Skip BFGS
#    7  5.00e+00  2.70e+01  2.35e+01  1.44e+02    3.26e+01      0   Skip BFGS
#    8  5.00e+00  2.22e+01  3.04e+01  1.74e+02    1.53e+02      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0809e+02
# 1 : |xc-x_last| = 1.2288e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.6945e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6945e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      9
# ------------------------- DONE! -------------------------
#    8  5.00e+00  2.85e+01  2.51e+01  1.54e+02    1.59e+02      1   Skip BFGS
#    9  5.00e+00  3.20e+01  2.53e+01  1.58e+02    1.49e+02      0
#    8  5.00e+00  3.84e+01  2.89e+01  1.83e+02    2.79e+02      1   Skip BFGS
#    8  5.00e+00  3.38e+01  2.41e+01  1.54e+02    9.09e+01      0   Skip BFGS
#    9  5.00e+00  2.15e+01  2.74e+01  1.59e+02    1.40e+02      1
#    9  5.00e+00  2.50e+01  2.94e+01  1.72e+02    3.52e+01      0
#    9  5.00e+00  2.82e+01  2.87e+01  1.72e+02    2.09e+02      1   Skip BFGS
#    9  5.00e+00  3.68e+01  2.76e+01  1.75e+02    2.22e+02      1   Skip BFGS
#    9  5.00e+00  2.80e+01  2.44e+01  1.50e+02    3.39e+01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1982e+02
# 1 : |xc-x_last| = 6.2957e-01 <= tolX*(1+|x0|) = 4.9538e+00
#    9  5.00e+00  2.66e+01  2.69e+01  1.61e+02    6.46e+01      0   Skip BFGS  0 : |proj(x-g)-x|    = 2.0944e+02 <= tolG          = 1.0000e-01
#
# 0 : |proj(x-g)-x|    = 2.0944e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    9  5.00e+00  2.80e+01  2.65e+01  1.61e+02    1.24e+02      1   Skip BFGS
#   10  5.00e+00  4.09e+01  2.25e+01  1.53e+02    2.39e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.8856e+00 <= tolF*(1+|f0|) = 1.0520e+02
# 1 : |xc-x_last| = 2.0630e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.3915e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.3915e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    9  5.00e+00  3.35e+01  2.19e+01  1.43e+02    9.82e+00      0
#    9  5.00e+00  2.22e+01  2.82e+01  1.63e+02    1.76e+02      1   Skip BFGS
#    8  5.00e+00  2.77e+01  2.25e+01  1.40e+02    3.80e+01      1   Skip BFGS
#    9  5.00e+00  2.10e+01  2.79e+01  1.60e+02    3.30e+01      0
#    9  5.00e+00  2.95e+01  2.27e+01  1.43e+02    1.97e+02      1   Skip BFGS
#   10  5.00e+00  2.68e+01  2.70e+01  1.62e+02    3.08e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.2978e+01 <= tolF*(1+|f0|) = 1.1782e+02
# 1 : |xc-x_last| = 1.4562e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 3.0820e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0820e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  2.20e+01  2.51e+01  1.47e+02    1.64e+02      1
# ------------------------- STOP! -------------------------------------------------- STOP! -------------------------
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1834e+021 : |fc-fOld| = 1.1384e+01 <= tolF*(1+|f0|) = 1.1932e+02
#
# 1 : |xc-x_last| = 1.3791e-01 <= tolX*(1+|x0|) = 4.9538e+00  10  5.00e+00  2.90e+01  2.29e+01  1.44e+02    1.77e+01      0   Skip BFGS  1 : |xc-x_last| = 9.8669e-01 <= tolX*(1+|x0|) = 4.9538e+00
#
#
# 0 : |proj(x-g)-x|    = 1.7576e+02 <= tolG          = 1.0000e-01------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 1.6369e+02 <= tolG          = 1.0000e-01
#
#
# 0 : |proj(x-g)-x|    = 1.7576e+02 <= 1e3*eps       = 1.0000e-021 : |fc-fOld| = 6.4223e+00 <= tolF*(1+|f0|) = 9.8734e+010 : |proj(x-g)-x|    = 1.6369e+02 <= 1e3*eps       = 1.0000e-02
#
#
# 1 : maxIter   =      10    <= iter          =     101 : maxIter   =      10    <= iter          =     101 : |xc-x_last| = 1.3372e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
#
# ------------------------- DONE! -------------------------------------------------- DONE! -------------------------0 : |proj(x-g)-x|    = 1.7722e+01 <= tolG          = 1.0000e-01
#
#
# 0 : |proj(x-g)-x|    = 1.7722e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  2.93e+01  2.66e+01  1.62e+02    1.92e+02      1
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 9.5881e+00 <= tolF*(1+|f0|) = 1.1919e+02
# 1 : |xc-x_last| = 1.3729e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.9224e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9224e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  2.51e+01  2.61e+01  1.55e+02    1.72e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 5.1137e+00 <= tolF*(1+|f0|) = 1.1554e+02
# 1 : |xc-x_last| = 1.4242e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.7210e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.7210e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  2.56e+01  2.46e+01  1.49e+02    4.06e+01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.2354e+01 <= tolF*(1+|f0|) = 1.0208e+02
# 1 : |xc-x_last| = 1.5545e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 4.0614e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.0614e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  3.35e+01  2.09e+01  1.38e+02    8.96e+01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.6915e+00 <= tolF*(1+|f0|) = 9.5167e+01
# 1 : |xc-x_last| = 1.9989e+00 <= tolX*(1+|x0|) = 4.9538e+00  10  5.00e+00  2.00e+01  2.18e+01  1.29e+02    1.81e+01      0
#
# 0 : |proj(x-g)-x|    = 8.9621e+01 <= tolG          = 1.0000e-01------------------------- STOP! -------------------------
#
# 0 : |proj(x-g)-x|    = 8.9621e+01 <= 1e3*eps       = 1.0000e-021 : |fc-fOld| = 1.3872e+01 <= tolF*(1+|f0|) = 1.1074e+02
# 1 : maxIter   =      10    <= iter          =     10
#
# 1 : |xc-x_last| = 1.5179e-01 <= tolX*(1+|x0|) = 4.9538e+00------------------------- DONE! -------------------------
#
# 0 : |proj(x-g)-x|    = 1.8072e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8072e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  2.41e+01  2.53e+01  1.51e+02    1.65e+02      1
# ------------------------- STOP! -------------------------   9  5.00e+00  2.86e+01  2.14e+01  1.35e+02    4.78e+01      1   Skip BFGS
#
# 1 : |fc-fOld| = 9.8297e+00 <= tolF*(1+|f0|) = 1.1981e+02
# 1 : |xc-x_last| = 1.3035e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.6498e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6498e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#   10  5.00e+00  3.06e+01  1.96e+01  1.29e+02    6.94e+01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 6.6138e+00 <= tolF*(1+|f0|) = 9.1376e+01
# 1 : |xc-x_last| = 1.6572e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 6.9408e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.9408e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------

# %%
target_0_keys = [k for k in inv_dict.keys() if "target_0" in k]

# %%
recovered_models = {}

for k in model_keys:
    recovered_models[k] = np.vstack([
        inv_dict[f"{k}_{ind}"] for ind in range(rx_locs.shape[0])
    ]).T

# %%
mesh_invert = discretize.TensorMesh([(np.r_[thicknesses1d, thicknesses1d[-1]])], origin="0")

# %%
with open("./synthetic-data/true-models.pkl", "rb") as f:
    true_models = pickle.load(f)

# %%
tree_mesh = discretize.load_mesh("./synthetic-data/treemesh.json")
# Out:
# /home/lheagy/miniforge3/envs/py311/lib/python3.11/site-packages/discretize/utils/io_utils.py:39: FutureWarning: In discretize v1.0 the TreeMesh will change the default value of diagonal_balance to True, which will likely slightly change meshes you have previously created. If you need to keep the current behavior, explicitly set diagonal_balance=False.
#   data = cls(**jsondict)

# %%
tree_mesh
# Out:
# OcTreeMesh: 0.01% filled
#
# Level : Number of cells               Mesh Extent               Cell Widths
# -----------------------           min     ,     max            min   ,   max
#   3   :       448            ---------------------------   --------------------
#   4   :       392         x:    -5120.0   ,   5120.0          10.0   ,   1280.0
#   5   :       624         y:    -5120.0   ,   5120.0          10.0   ,   1280.0
#   6   :      1568         z:    -5120.0   ,   5120.0          10.0   ,   1280.0
#   7   :      2772
#   8   :      43744
#   9   :      42516
#  10   :      28512
# -----------------------
# Total :     120576

# %%
key = "target_45"

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 6))

norm = LogNorm(vmin=1e-3, vmax=1/20)

plt.colorbar(ax[0].pcolor(
    rx_locs[:, 0], -mesh_invert.cell_centers, np.exp(recovered_models[key]), norm=norm
), ax=ax[0])

plt.colorbar(
    tree_mesh.plot_slice(
        true_models[key], pcolor_opts={"norm":norm}, ax=ax[1],
        normal="y"
    )[0], ax=ax[1]
)

for a in ax: 
    a.set_ylim(np.r_[-250, 0])
    a.set_xlim(np.r_[-500, 500])
    a.set_aspect(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       1 fig, ax = plt.subplots(2, 1, figsize=(12, 6))
#       3 norm = LogNorm(vmin=1e-3, vmax=1/20)
#       5 plt.colorbar(ax[0].pcolor(
# ----> 6     rx_locs[:, 0], -mesh_invert.cell_centers, np.exp(recovered_models[key]), norm=norm
#       7 ), ax=ax[0])
#       9 plt.colorbar(
#      10     tree_mesh.plot_slice(
#      11         true_models[key], pcolor_opts={"norm":norm}, ax=ax[1],
#      12         normal="y"
#      13     )[0], ax=ax[1]
#      14 )
#      16 for a in ax:
#
# NameError: name 'rx_locs' is not defined
