# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import time
import pickle

from concurrent.futures import ProcessPoolExecutor, as_completed

import discretize 
from simpeg.utils import mkvc, plot_1d_layer_model
from simpeg import (
    maps,
    Data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils,
)
from simpeg.electromagnetics import time_domain as tdem
from simpeg.utils.solver_utils import get_default_solver

from simpeg.meta import MultiprocessingMetaSimulation #DaskMetaSimulation

# %%
Solver = get_default_solver()
Solver
# Out:
# pymatsolver.direct.pardiso.Pardiso

# %% [markdown]
# # load data

# %%
directory = "./synthetic-data-10m"
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f)) and f.split(".")[-1]=="txt"]

print(files)
# Out:
# ['rx_times.txt', 'background.txt', 'target_30.txt', 'target_45.txt', 'target_0.txt', 'rx_locs.txt', 'target_15.txt']

# %%
files
# Out:
# ['rx_times.txt',
#  'background.txt',
#  'target_30.txt',
#  'target_45.txt',
#  'target_0.txt',
#  'rx_locs.txt',
#  'target_15.txt']

# %%
files.remove("rx_locs.txt")
rx_locs = np.loadtxt(f"{directory}/rx_locs.txt")

files.remove("rx_times.txt")
rx_times = np.loadtxt(f"{directory}/rx_times.txt")

# %%
dobs_dict = {}

for f in files: 
    key = f.split(".")[0]
    dobs_dict[key] = np.loadtxt(f"{directory}/{f}")

# %% [markdown]
# # create survey

# %%
tx_height = rx_locs[0, 2]
source_list = []

for i in range(rx_locs.shape[0]): 
    rx = tdem.receivers.PointMagneticFluxTimeDerivative(rx_locs[i, :], rx_times, orientation="z")
    src = tdem.sources.CircularLoop(
        receiver_list=[rx], location=rx_locs[i, :], orientation="z", radius=10, 
        waveform=tdem.sources.StepOffWaveform()
    )
    source_list.append(src)

full_survey = tdem.Survey(source_list)

# %%
data_dict = {}

for key, value in dobs_dict.items(): 
    data_dict[key] = Data(survey=full_survey, dobs=value, relative_error=0.05)

# %%
ind = 25
rx_locs[ind, :]
# Out:
# array([-255.,    0.,   30.])

# %%
key = "target_0"
ind = 25
src = full_survey.source_list[ind]

plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
plt.loglog(rx_times, -data_dict[key][src, src.receiver_list[0]], "C0-o", ms=4)

# %%
# octree_mesh = discretize.load_mesh("./synthetic-data/treemesh.json")

# octree_mesh = discretize.load_mesh()

# %%
cs = 5
core_region = 200
npad = 20
padding_factor = 1.3

thicknesses1d = discretize.utils.unpack_widths(
    [(cs, np.int64(np.ceil(core_region/cs))), (cs, npad, padding_factor)]
)

# %%
np.sum(thicknesses1d)
# Out:
# np.float64(4296.075484557508)

# %%
# set up 1D inversion 
def create_inversion(
    key, ind, dobs, n_times_invert=20, 
): 
    relative_error=0.1
    noise_floor=1e-11
    alpha_s = 1/cs**2
    alpha_x = 1
    rho_back = 500
    beta0 = 10
    
    rx_times_invert = rx_times[:n_times_invert]
    
    # def create inv
    # src = full_survey.source_list[ind]
    # rx = src.receiver_list[0]
    
    rx_sounding = tdem.receivers.PointMagneticFluxTimeDerivative(
        locations=rx_locs[ind, :], times=rx_times_invert, orientation="z"
    )
    src_sounding = tdem.sources.CircularLoop(
        receiver_list=[rx_sounding], location=rx_locs[ind, :], orientation="z", 
        radius=10, 
        waveform=tdem.sources.StepOffWaveform()
    )
    survey_sounding = tdem.Survey([src_sounding])
    mesh_invert = discretize.TensorMesh([(np.r_[thicknesses1d, thicknesses1d[-1]])], origin="0")
    
    sim1d = tdem.Simulation1DLayered(
        survey=survey_sounding, thicknesses=thicknesses1d, sigmaMap=maps.ExpMap(mesh_invert)
    )
    
    data_invert = Data(
        survey_sounding, 
        dobs=dobs[:n_times_invert],
        relative_error=relative_error,
        noise_floor=noise_floor
    )
    
    dmis = data_misfit.L2DataMisfit(simulation=sim1d, data=data_invert)
    reg = regularization.WeightedLeastSquares(
        mesh_invert, alpha_s=alpha_s, alpha_x=alpha_x, 
        # reference_model=np.log(1./rho_back),
        # norms=norms
    )
    
    opt = optimization.InexactGaussNewton(maxIter=10)
    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=beta0)
    
    # Defining a starting value for the trade-off parameter (beta) between the data
    # misfit and the regularization.
    # starting_beta = directives.BetaEstimate_ByEig(beta0_ratio=10)
    
    cool_beta = directives.BetaSchedule(coolingFactor=1.5, coolingRate=1)
    
    # Update the preconditionner
    update_Jacobi = directives.UpdatePreconditioner()
    
    # Options for outputting recovered models and predicted data for each beta.
    save_iteration = directives.SaveOutputDictEveryIteration(
        saveOnDisk=False, name=f"inv-dict-{rx.locations[0,0]}"
    )
    
    
    # Updating the preconditionner if it is model dependent.
    update_jacobi = directives.UpdatePreconditioner()
    
    # Add sensitivity weights
    sensitivity_weights = directives.UpdateSensitivityWeights()
    
    target_misfit = directives.TargetMisfit()
    
    # The directives are defined as a list.
    directives_list = [
        sensitivity_weights,
        update_jacobi,
        # starting_beta,
        # cool_beta,
        save_iteration,
        target_misfit,
    ]
    
    # Here we combine the inverse problem and the set of directives
    inv = inversion.BaseInversion(inv_prob, directives_list)
    return inv

# %%
directory = "./synthetic-invs-1d-10m"

# %%
def run_inv(key, ind, dobs): 
    inv = create_inversion(key, ind, dobs)
    rho_start = 500
    m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
    
    label_key=f"{key}_{ind}"
    
    mopt = inv.run(m0)
    np.save(f"{directory}/{label_key}_model.npy", mopt)
    
    inv_dict = inv.directiveList.dList[-2].outDict
    with open(f"{directory}/{label_key}_inv_dict.pkl", "wb") as f:
        pickle.dump(inv_dict, f)

    return label_key, mopt

# %%
# key = "target_0"
# n_times_invert = 20
# ind = 0
# src = full_survey.source_list[ind]
# rx = src.receiver_list[0]
# dobs = data_dict[key][src, rx][:n_times_invert]

# inv = create_inversion(key, ind, dobs)

# %%
# rho_start = 500
# m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
# mopt = inv.run(m0)

# %%
# iterations = len(inv.directiveList.dList[-2].outDict)

# %%
# # plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
# # plt.loglog(rx_times, -data_dict[key][src, rx], "C0o", ms=4)
# rx_times_invert = rx_times[:n_times_invert]
# plt.errorbar(rx_times_invert, -inv.invProb.dmisfit[0][1].data.dobs, yerr=inv.invProb.dmisfit[0][1].data.standard_deviation)
# plt.loglog(rx_times_invert, -inv.directiveList.dList[-2].outDict[iterations]["dpred"], "C1-s", ms=4)

# %%
# rho_back = 500
# sigma_back = 1./rho_back 

# rho_target = 20
# sigma_target = 1./rho_target
# target_z_center = -60
# target_thickness = 40

# model_true = np.log(1/np.r_[rho_back, rho_target, rho_back])

# thicknesses_true = np.r_[-target_z_center - target_thickness/2, target_thickness]

# %%
# fig, ax = plt.subplots(1, 1, figsize=(2, 4))
# plot_1d_layer_model(
#     thicknesses1d, np.exp(mopt), ax=ax, color="C0", label="recovered"
# )
# plot_1d_layer_model(
#     thicknesses_true, np.exp(model_true), ax=ax, color="k", label="true"
# )
# ax.set_ylim([250, 0])
# ax.set_xlim([1e-4, 1e-1])

# %%
model_keys = list(data_dict.keys())[1:]
model_keys
# Out:
# ['target_30', 'target_45', 'target_0', 'target_15']

# %%
rx_locs.shape
# Out:
# (102, 3)

# %%
inv_dict = {}
n_times_invert = 20

# key = model_keys[0]
with ProcessPoolExecutor() as executor:
    futures = []
    for key in model_keys: 
        for ind in range(rx_locs.shape[0]): 
            src = full_survey.source_list[ind]
            rx = src.receiver_list[0]
            dobs = data_dict[key][src, rx][:n_times_invert]
            futures.append(
                executor.submit(run_inv, key, ind, dobs)
            )
            
    for future in as_completed(futures):
        label_key, mopt = future.result()
        inv_dict[label_key] = mopt
# Out:
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
#
#
#
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================model has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# -----------------------------------------------------------------------------
# ============================ Inexact Gauss Newton ============================x0 has any nan: 0
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# model has any nan: 0
# x0 has any nan: 0============================ Inexact Gauss Newton ============================
#
# model has any nan: 0model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# model has any nan: 0============================ Inexact Gauss Newton ============================
#
# -----------------------------------------------------------------------------
# ============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
#
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------model has any nan: 0
#
# x0 has any nan: 0============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
# model has any nan: 0
#
# x0 has any nan: 0
#
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
#
#
# x0 has any nan: 0x0 has any nan: 0
# model has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
#
# model has any nan: 0============================ Inexact Gauss Newton ============================
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# ============================ Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0model has any nan: 0
#
# x0 has any nan: 0
# -----------------------------------------------------------------------------
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================
# -----------------------------------------------------------------------------
#
# x0 has any nan: 0x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# -----------------------------------------------------------------------------
#
# model has any nan: 0
# x0 has any nan: 0============================ Inexact Gauss Newton ============================
#
# model has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------model has any nan: 0model has any nan: 0x0 has any nan: 0
#
#
# ============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
#
# x0 has any nan: 0
# model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# model has any nan: 0-----------------------------------------------------------------------------
#
#
# model has any nan: 0============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================
#
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0x0 has any nan: 0
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
# model has any nan: 0model has any nan: 0model has any nan: 0x0 has any nan: 0-----------------------------------------------------------------------------
#
# ============================ Inexact Gauss Newton ============================
#
#
#
#
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================x0 has any nan: 0
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================
#
# model has any nan: 0model has any nan: 0model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
#
# ============================ Inexact Gauss Newton ============================
#
# model has any nan: 0
#
# -----------------------------------------------------------------------------============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================-----------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================x0 has any nan: 0-----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#
# ============================ Inexact Gauss Newton ============================
# x0 has any nan: 0-----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# x0 has any nan: 0
#
# x0 has any nan: 0
#
#
#
#
# x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# x0 has any nan: 0
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
# x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ----------------------------------------------------------------------------------------------------------------------------------------------------------
#
# x0 has any nan: 0model has any nan: 0-----------------------------------------------------------------------------
# model has any nan: 0
#
#
#
# model has any nan: 0model has any nan: 0-----------------------------------------------------------------------------x0 has any nan: 0x0 has any nan: 0
# ============================ Inexact Gauss Newton ============================model has any nan: 0
#
#
#
#
# -----------------------------------------------------------------------------
#
# ============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================model has any nan: 0model has any nan: 0model has any nan: 0
#
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0model has any nan: 0
# x0 has any nan: 0
# x0 has any nan: 0model has any nan: 0============================ Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================
# x0 has any nan: 0
# -----------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
#
#
#
#
# -----------------------------------------------------------------------------
# model has any nan: 0
#
# model has any nan: 0
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================model has any nan: 0============================ Inexact Gauss Newton ======================================================== Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   model has any nan: 0x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment     #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
#
#
#
#
#
#
#
# ============================ Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ============================ Inexact Gauss Newton ============================  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   -----------------------------------------------------------------------------============================ Inexact Gauss Newton ============================
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
#
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   ----------------------------------------------------------------------------------------------------------------------------------------------------------
# x0 has any nan: 0
#
# -----------------------------------------------------------------------------x0 has any nan: 0
#
#
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0
# -----------------------------------------------------------------------------x0 has any nan: 0
# x0 has any nan: 0
# x0 has any nan: 0
#
#
#
# -----------------------------------------------------------------------------  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
#
# ============================ Inexact Gauss Newton ============================x0 has any nan: 0
#
#
#
#
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
#
# x0 has any nan: 0-----------------------------------------------------------------------------
#
#
# x0 has any nan: 0  #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0-----------------------------------------------------------------------------x0 has any nan: 0
#
#
#
# x0 has any nan: 0
#
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment   x0 has any nan: 0
#
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# x0 has any nan: 0x0 has any nan: 0
#
#    0  1.00e+01  1.76e+02  0.00e+00  1.76e+02    1.03e+02      0                 0  1.00e+01  5.18e+02  0.00e+00  5.18e+02    1.05e+02      0
#    0  1.00e+01  1.03e+02  0.00e+00  1.03e+02    8.64e+01      0
#
#    0  1.00e+01  7.14e+01  0.00e+00  7.14e+01    7.50e+01      0
#    0  1.00e+01  5.61e+02  0.00e+00  5.61e+02    1.02e+02      0                 0  1.00e+01  1.91e+02  0.00e+00  1.91e+02    1.05e+02      0                 0  1.00e+01  4.98e+02  0.00e+00  4.98e+02    1.07e+02      0                 0  1.00e+01  6.28e+02  0.00e+00  6.28e+02    9.07e+01      0
#
#
#
#    0  1.00e+01  1.35e+02  0.00e+00  1.35e+02    9.49e+01      0                 0  1.00e+01  8.50e+02  0.00e+00  8.50e+02    6.28e+01      0
#
#    0  1.00e+01  3.09e+02  0.00e+00  3.09e+02    1.12e+02      0
#    0  1.00e+01  5.75e+02  0.00e+00  5.75e+02    9.89e+01      0
#    0  1.00e+01  1.12e+02  0.00e+00  1.12e+02    8.93e+01      0                 0  1.00e+01  5.48e+02  0.00e+00  5.48e+02    1.03e+02      0
#
#    0  1.00e+01  3.79e+02  0.00e+00  3.79e+02    1.12e+02      0
#    0  1.00e+01  2.65e+02  0.00e+00  2.65e+02    1.11e+02      0
#    0  1.00e+01  7.58e+02  0.00e+00  7.58e+02    7.32e+01      0                 0  1.00e+01  3.31e+02  0.00e+00  3.31e+02    1.13e+02      0
#    0  1.00e+01  8.79e+02  0.00e+00  8.79e+02    6.05e+01      0                 0  1.00e+01  7.81e+01  0.00e+00  7.81e+01    7.78e+01      0
#
#    0  1.00e+01  8.86e+02  0.00e+00  8.86e+02    6.16e+01      0
#    0  1.00e+01  1.61e+02  0.00e+00  1.61e+02    1.00e+02      0
#
#    0  1.00e+01  4.28e+02  0.00e+00  4.28e+02    1.10e+02      0
#    0  1.00e+01  5.95e+02  0.00e+00  5.95e+02    9.56e+01      0                 0  1.00e+01  5.36e+02  0.00e+00  5.36e+02    1.04e+02      0                 0  1.00e+01  7.15e+02  0.00e+00  7.15e+02    7.87e+01      0                 0  1.00e+01  5.65e+02  0.00e+00  5.65e+02    1.01e+02      0                 0  1.00e+01  6.52e+01  0.00e+00  6.52e+01    7.23e+01      0
#    0  1.00e+01  2.08e+02  0.00e+00  2.08e+02    1.07e+02      0                 0  1.00e+01  9.37e+01  0.00e+00  9.37e+01    8.35e+01      0                 0  1.00e+01  8.88e+02  0.00e+00  8.88e+02    6.07e+01      0
#
#
#
#    0  1.00e+01  2.26e+02  0.00e+00  2.26e+02    1.09e+02      0                 0  1.00e+01  8.56e+01  0.00e+00  8.56e+01    8.06e+01      0
#    0  1.00e+01  3.55e+02  0.00e+00  3.55e+02    1.13e+02      0                 0  1.00e+01  8.67e+02  0.00e+00  8.67e+02    6.13e+01      0                 0  1.00e+01  8.86e+02  0.00e+00  8.86e+02    6.03e+01      0                 0  1.00e+01  1.47e+02  0.00e+00  1.47e+02    9.76e+01      0                 0  1.00e+01  7.95e+02  0.00e+00  7.95e+02    6.87e+01      0
#
#
#    0  1.00e+01  6.70e+02  0.00e+00  6.70e+02    8.48e+01      0
#
#
#
#    0  1.00e+01  1.23e+02  0.00e+00  1.23e+02    9.21e+01      0
#
#    0  1.00e+01  2.87e+02  0.00e+00  2.87e+02    1.12e+02      0                 0  1.00e+01  8.81e+02  0.00e+00  8.81e+02    6.28e+01      0
#
#
#    0  1.00e+01  4.52e+02  0.00e+00  4.52e+02    1.09e+02      0                 0  1.00e+01  4.03e+02  0.00e+00  4.03e+02    1.11e+02      0
#
#
#    0  1.00e+01  5.57e+02  0.00e+00  5.57e+02    1.02e+02      0
#    0  1.00e+01  8.26e+02  0.00e+00  8.26e+02    6.53e+01      0
#    0  1.00e+01  2.45e+02  0.00e+00  2.45e+02    1.10e+02      0
#    0  1.00e+01  4.76e+02  0.00e+00  4.76e+02    1.08e+02      0
# ------------------------- STOP! -------------------------
# ------------------------- STOP! -------------------------------------------------- STOP! -------------------------1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.2367e+00
#
# 1 : |xc-x_last| = 1.8980e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7675e+01
#
# 0 : |proj(x-g)-x|    = 7.5028e+01 <= tolG          = 1.0000e-01
# 1 : |xc-x_last| = 3.4226e+00 <= tolX*(1+|x0|) = 4.9538e+000 : |proj(x-g)-x|    = 7.5028e+01 <= 1e3*eps       = 1.0000e-02
#
#
# 0 : maxIter   =      10    <= iter          =      11 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0371e+01
# 0 : |proj(x-g)-x|    = 1.0263e+02 <= tolG          = 1.0000e-01------------------------- DONE! -------------------------
#
# 0 : |proj(x-g)-x|    = 1.0263e+02 <= 1e3*eps       = 1.0000e-02
#
# 1 : |xc-x_last| = 2.3857e+00 <= tolX*(1+|x0|) = 4.9538e+000 : maxIter   =      10    <= iter          =      1
#
# Running inversion with SimPEG v0.24.0
# ------------------------- DONE! -------------------------0 : |proj(x-g)-x|    = 8.6388e+01 <= tolG          = 1.0000e-01
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# ------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 8.6388e+01 <= 1e3*eps       = 1.0000e-02
# simpeg.InvProblem will set Regularization.reference_model to m0.
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.9248e+01
#
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3576e+01
# 1 : |xc-x_last| = 3.6364e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 1 : |xc-x_last| = 2.8521e+00 <= tolX*(1+|x0|) = 4.9538e+000 : maxIter   =      10    <= iter          =      1
#
# 0 : |proj(x-g)-x|    = 9.4930e+01 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 1.0483e+02 <= tolG          = 1.0000e-01
#
# ------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 1.0483e+02 <= 1e3*eps       = 1.0000e-02
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# 0 : |proj(x-g)-x|    = 9.4930e+01 <= 1e3*eps       = 1.0000e-02simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1346e+01------------------------- DONE! -------------------------0 : maxIter   =      10    <= iter          =      1
#
#
#
#
#
# 0 : maxIter   =      10    <= iter          =      11 : |xc-x_last| = 2.5302e+00 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- DONE! -------------------------
# 0 : |proj(x-g)-x|    = 8.9270e+01 <= tolG          = 1.0000e-01
# ------------------------- DONE! -------------------------
# simpeg.InvProblem will set Regularization.reference_model to m0.
#    1  1.00e+01  3.03e+02  9.54e+00  3.99e+02    4.09e+02      0              0 : |proj(x-g)-x|    = 8.9270e+01 <= 1e3*eps       = 1.0000e-02
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.0 : maxIter   =      10    <= iter          =      1
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.------------------------- STOP! -------------------------
#
# ------------------------- STOP! -------------------------
# ------------------------- STOP! -------------------------
#
# ------------------------- STOP! -------------------------
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# ------------------------- DONE! -------------------------simpeg.InvProblem will set Regularization.reference_model to m0.
# ------------------------- STOP! -------------------------
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.9115e+00
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.4841e+01------------------------- STOP! -------------------------1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6645e+01
# ------------------------- STOP! -------------------------simpeg.InvProblem will set Regularization.reference_model to m0.------------------------- STOP! -------------------------------------------------- STOP! -------------------------1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.4728e+00
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6200e+01
# simpeg.InvProblem will set Regularization.reference_model to m0.
#    1  1.00e+01  4.48e+02  1.12e+01  5.60e+02    5.42e+02      0
#    1  1.00e+01  4.69e+02  1.70e+01  6.39e+02    3.75e+02      0              1 : |xc-x_last| = 2.2500e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#    1  1.00e+01  2.57e+02  8.83e+00  3.45e+02    3.64e+02      0
# 1 : |xc-x_last| = 2.0068e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0941e+01
# 1 : |xc-x_last| = 4.6166e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |xc-x_last| = 3.0306e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2418e+01
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#    1  1.00e+01  2.73e+01  4.09e+00  6.82e+01    6.70e+01      0
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.6201e+00
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# 0 : |proj(x-g)-x|    = 8.3484e+01 <= tolG          = 1.0000e-01
#
# 1 : |xc-x_last| = 3.2199e+00 <= tolX*(1+|x0|) = 4.9538e+00
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.6584e+00
#
#
# 0 : |proj(x-g)-x|    = 1.1113e+02 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 7.7783e+01 <= tolG          = 1.0000e-01
#
# 1 : |xc-x_last| = 3.8641e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |xc-x_last| = 2.6862e+00 <= tolX*(1+|x0|) = 4.9538e+00simpeg.InvProblem will set Regularization.reference_model to m0.
#
# 0 : |proj(x-g)-x|    = 9.7642e+01 <= tolG          = 1.0000e-01
#
#
# 0 : |proj(x-g)-x|    = 8.3484e+01 <= 1e3*eps       = 1.0000e-02simpeg.InvProblem will set Regularization.reference_model to m0.   1  1.00e+01  3.47e+01  4.62e+00  8.09e+01    7.48e+01      0
#
#
# 1 : |xc-x_last| = 2.1245e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : |proj(x-g)-x|    = 1.1113e+02 <= 1e3*eps       = 1.0000e-02   1  1.00e+01  4.15e+02  1.74e+01  5.89e+02    3.19e+02      0              0 : |proj(x-g)-x|    = 1.0021e+02 <= tolG          = 1.0000e-01
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# 0 : |proj(x-g)-x|    = 9.2140e+01 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 9.7642e+01 <= 1e3*eps       = 1.0000e-02
#
#    1  1.00e+01  5.33e+01  5.83e+00  1.12e+02    9.12e+01      0                 1  1.00e+01  4.84e+02  1.88e+01  6.72e+02    4.13e+02      0
# 1 : |xc-x_last| = 2.2121e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : |proj(x-g)-x|    = 1.0021e+02 <= 1e3*eps       = 1.0000e-02
# 0 : |proj(x-g)-x|    = 7.7783e+01 <= 1e3*eps       = 1.0000e-020 : maxIter   =      10    <= iter          =      1------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 8.0621e+01 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 9.2140e+01 <= 1e3*eps       = 1.0000e-02
#
#
# 0 : |proj(x-g)-x|    = 1.0682e+02 <= tolG          = 1.0000e-010 : maxIter   =      10    <= iter          =      10 : maxIter   =      10    <= iter          =      1
#
#
# 0 : maxIter   =      10    <= iter          =      1------------------------- DONE! -------------------------------------------------- STOP! -------------------------
#
#
#
# 0 : maxIter   =      10    <= iter          =      10 : |proj(x-g)-x|    = 7.2334e+01 <= tolG          = 1.0000e-01------------------------- DONE! -------------------------
# 0 : |proj(x-g)-x|    = 1.0682e+02 <= 1e3*eps       = 1.0000e-02
#
#
# 0 : maxIter   =      10    <= iter          =      1
#
#
#
# Running inversion with SimPEG v0.24.0
# 0 : |proj(x-g)-x|    = 8.0621e+01 <= 1e3*eps       = 1.0000e-02
#    1  1.00e+01  3.84e+02  1.07e+01  4.91e+02    4.84e+02      0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.2733e+01
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4643e+01simpeg.InvProblem will set Regularization.reference_model to m0.------------------------- DONE! -------------------------
# 0 : |proj(x-g)-x|    = 7.2334e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# 0 : maxIter   =      10    <= iter          =      1------------------------- DONE! -------------------------simpeg.InvProblem will set Regularization.reference_model to m0.   1  1.00e+01  3.47e+02  1.02e+01  4.49e+02    4.50e+02      0              ------------------------- DONE! -------------------------
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#    1  1.00e+01  4.48e+02  1.84e+01  6.32e+02    3.71e+02      0
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# ------------------------- DONE! -------------------------
# 1 : |xc-x_last| = 4.1027e+00 <= tolX*(1+|x0|) = 4.9538e+00simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# 1 : |xc-x_last| = 4.3547e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#    1  1.00e+01  4.33e+01  5.20e+00  9.53e+01    8.29e+01      0
# Running inversion with SimPEG v0.24.0
#
#
# ...
# 1 : |xc-x_last| = 9.8859e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.9329e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.9329e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      9
# ------------------------- DONE! -------------------------
#    0  1.00e+01  2.19e+02  0.00e+00  2.19e+02    1.04e+02      0
#    0  1.00e+01  2.07e+02  0.00e+00  2.07e+02    1.02e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.3589e+01   8  1.00e+01  2.10e+01  1.30e+01  1.51e+02    8.76e+01      0   Skip BFGS
#
# 1 : |xc-x_last| = 2.3642e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 3.4385e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.4385e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
#    1  1.00e+01  6.58e+01  7.05e+00  1.36e+02    8.20e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.6079e+01
# 1 : |xc-x_last| = 2.5202e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 3.8038e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.8038e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- STOP! -------------------------------------------------- DONE! -------------------------
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.8477e+01
# 1 : |xc-x_last| = 2.4733e+00 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 1.6443e+01 <= tolG          = 1.0000e-01
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.1035e+01
# 0 : |proj(x-g)-x|    = 1.6443e+01 <= 1e3*eps       = 1.0000e-021 : |xc-x_last| = 2.2103e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : maxIter   =      10    <= iter          =      4------------------------- STOP! -------------------------
# 0 : |proj(x-g)-x|    = 3.0381e+01 <= tolG          = 1.0000e-01
# ------------------------- DONE! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.5696e+01
# 0 : |proj(x-g)-x|    = 3.0381e+01 <= 1e3*eps       = 1.0000e-02
# 1 : |xc-x_last| = 1.8999e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : maxIter   =      10    <= iter          =      40 : |proj(x-g)-x|    = 2.1881e+01 <= tolG          = 1.0000e-01
#
# ------------------------- DONE! -------------------------0 : |proj(x-g)-x|    = 2.1881e+01 <= 1e3*eps       = 1.0000e-02
#
# 0 : maxIter   =      10    <= iter          =      4
# ------------------------- DONE! -------------------------
#    8  1.00e+01  2.04e+01  1.36e+01  1.56e+02    9.47e+00      0
#    1  1.00e+01  5.47e+01  6.38e+00  1.19e+02    7.55e+01      0
#    1  1.00e+01  7.89e+01  7.77e+00  1.57e+02    8.88e+01      0
# ------------------------- STOP! -------------------------------------------------- STOP! -------------------------
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.8392e+011 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1982e+02
#
# 1 : |xc-x_last| = 2.0550e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |xc-x_last| = 9.6352e-01 <= tolX*(1+|x0|) = 4.9538e+00
#
# 0 : |proj(x-g)-x|    = 9.4297e+00 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 2.6109e+01 <= tolG          = 1.0000e-01
#
# 0 : |proj(x-g)-x|    = 9.4297e+00 <= 1e3*eps       = 1.0000e-020 : |proj(x-g)-x|    = 2.6109e+01 <= 1e3*eps       = 1.0000e-02
#
# 0 : maxIter   =      10    <= iter          =      90 : maxIter   =      10    <= iter          =      4
#
# ------------------------- DONE! -------------------------------------------------- DONE! -------------------------
#
#    1  1.00e+01  9.38e+01  8.55e+00  1.79e+02    9.56e+01      0
#   10  1.00e+01  2.07e+01  1.23e+01  1.43e+02    9.22e+01      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 6.5139e+00 <= tolF*(1+|f0|) = 1.1782e+02
# 1 : |xc-x_last| = 8.5181e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 9.2194e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.2194e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.7520e+01
# 1 : |xc-x_last| = 4.7298e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.0873e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0873e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
#   10  1.00e+01  2.47e+01  1.17e+01  1.42e+02    1.30e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 4.2857e+00 <= tolF*(1+|f0|) = 1.1680e+02
# 1 : |xc-x_last| = 1.2962e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.2999e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.2999e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    1  1.00e+01  4.54e+01  5.77e+00  1.03e+02    6.92e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.9104e+01
# 1 : |xc-x_last| = 4.9413e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.0967e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0967e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.4610e+01
# 1 : |xc-x_last| = 4.3409e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.0645e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0645e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
#   10  1.00e+01  2.76e+01  1.01e+01  1.29e+02    1.63e+01      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.6263e-01 <= tolF*(1+|f0|) = 1.1398e+02
# 1 : |xc-x_last| = 3.5639e-01 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 1.6289e+01 <= tolG          = 1.0000e-01
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.3263e+01
# 0 : |proj(x-g)-x|    = 1.6289e+01 <= 1e3*eps       = 1.0000e-021 : |xc-x_last| = 4.1605e+00 <= tolX*(1+|x0|) = 4.9538e+00
#
# 1 : maxIter   =      10    <= iter          =     100 : |proj(x-g)-x|    = 1.0512e+02 <= tolG          = 1.0000e-01
#
# ------------------------- DONE! -------------------------0 : |proj(x-g)-x|    = 1.0512e+02 <= 1e3*eps       = 1.0000e-02
#
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- STOP! -------------------------------------------------- DONE! -------------------------
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1860e+02
# 1 : |xc-x_last| = 9.0528e-01 <= tolX*(1+|x0|) = 4.9538e+00
# ------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 9.9487e+00 <= tolG          = 1.0000e-01
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0759e+010 : |proj(x-g)-x|    = 9.9487e+00 <= 1e3*eps       = 1.0000e-02
#
# 1 : |xc-x_last| = 4.4934e+00 <= tolX*(1+|x0|) = 4.9538e+001 : maxIter   =      10    <= iter          =     10
#
# ------------------------- DONE! -------------------------0 : |proj(x-g)-x|    = 1.0211e+02 <= tolG          = 1.0000e-01
# ------------------------- STOP! -------------------------
#
# 0 : |proj(x-g)-x|    = 1.0211e+02 <= 1e3*eps       = 1.0000e-021 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1958e+02
#
# 1 : |xc-x_last| = 1.0008e+00 <= tolX*(1+|x0|) = 4.9538e+000 : maxIter   =      10    <= iter          =      1
#
# 0 : |proj(x-g)-x|    = 2.6037e+01 <= tolG          = 1.0000e-01------------------------- DONE! -------------------------
#
# 0 : |proj(x-g)-x|    = 2.6037e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      9
# ------------------------- DONE! -------------------------   2  1.00e+01  3.58e+01  4.18e+00  7.76e+01    2.18e+01      0
#
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1981e+02
# 1 : |xc-x_last| = 9.8508e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 8.7644e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.7644e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      9
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6020e+01
# 1 : |xc-x_last| = 4.5294e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.0765e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0765e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      1
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# ------------------------- STOP! -------------------------1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.1987e+01
#
# 1 : |xc-x_last| = 4.6274e+00 <= tolX*(1+|x0|) = 4.9538e+001 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1963e+02
#
# 1 : |xc-x_last| = 9.3331e-01 <= tolX*(1+|x0|) = 4.9538e+000 : |proj(x-g)-x|    = 1.0368e+02 <= tolG          = 1.0000e-01
#
# 0 : |proj(x-g)-x|    = 9.3028e+00 <= tolG          = 1.0000e-010 : |proj(x-g)-x|    = 1.0368e+02 <= 1e3*eps       = 1.0000e-02
#
# 0 : maxIter   =      10    <= iter          =      10 : |proj(x-g)-x|    = 9.3028e+00 <= 1e3*eps       = 1.0000e-02
#
# ------------------------- DONE! -------------------------0 : maxIter   =      10    <= iter          =      9
#
# ------------------------- DONE! -------------------------
#    1  1.00e+01  3.78e+01  5.22e+00  9.00e+01    6.35e+01      0
#    1  1.00e+01  3.17e+01  4.72e+00  7.90e+01    5.83e+01      0
#    1  1.00e+01  2.31e+01  3.89e+00  6.20e+01    4.96e+01      0
#   10  1.00e+01  2.66e+01  1.12e+01  1.38e+02    6.53e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.2704e+00 <= tolF*(1+|f0|) = 1.1554e+02
# 1 : |xc-x_last| = 8.2009e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 6.5283e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.5283e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      10    <= iter          =     10
# ------------------------- DONE! -------------------------
#    1  1.00e+01  2.01e+01  3.54e+00  5.56e+01    4.60e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.3651e+01
# 1 : |xc-x_last| = 3.4259e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 7.5462e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 7.5462e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------------------------------- STOP! -------------------------
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.6230e+01
# 1 : |xc-x_last| = 3.6098e+00 <= tolX*(1+|x0|) = 4.9538e+000 : |proj(x-g)-x|    = 8.2026e+01 <= tolG          = 1.0000e-01
#    1  1.00e+01  2.69e+01  4.29e+00  6.97e+01    5.37e+01      0
#
# 0 : |proj(x-g)-x|    = 8.2026e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
#    2  1.00e+01  2.37e+01  3.80e+00  6.17e+01    1.59e+01      0
#    2  1.00e+01  2.92e+01  3.99e+00  6.90e+01    1.88e+01      0              ------------------------- STOP! -------------------------
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.1172e+01
# 1 : |xc-x_last| = 3.2489e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 6.9236e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.9236e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1989e+02
# 1 : |xc-x_last| = 9.3099e-01 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 9.4723e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.4723e+00 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      9
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.4479e+01
# 1 : |xc-x_last| = 2.1407e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 2.1794e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.1794e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.6619e+01
# 1 : |xc-x_last| = 2.9216e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 5.8325e+01 <= tolG          = 1.0000e-01
# ------------------------- STOP! -------------------------0 : |proj(x-g)-x|    = 5.8325e+01 <= 1e3*eps       = 1.0000e-02
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.2609e+010 : maxIter   =      10    <= iter          =      2
#
# 1 : |xc-x_last| = 2.6308e+00 <= tolX*(1+|x0|) = 4.9538e+00------------------------- DONE! -------------------------
#
# 0 : |proj(x-g)-x|    = 4.9586e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.9586e+01 <= 1e3*eps       = 1.0000e-02
# ------------------------- STOP! -------------------------0 : maxIter   =      10    <= iter          =      2
#
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.8835e+01------------------------- DONE! -------------------------
#
# 1 : |xc-x_last| = 3.0813e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 6.3525e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.3525e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.0804e+01
# 1 : |xc-x_last| = 2.4998e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 4.5978e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.5978e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.4553e+01
# 1 : |xc-x_last| = 2.7720e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 5.3703e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.3703e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      2
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.8919e+01
# 1 : |xc-x_last| = 1.7464e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.5899e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.5899e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.1667e+01
# 1 : |xc-x_last| = 1.9407e+00 <= tolX*(1+|x0|) = 4.9538e+00
# 0 : |proj(x-g)-x|    = 1.8754e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8754e+01 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      10    <= iter          =      3
# ------------------------- DONE! -------------------------

# %%
target_0_keys = [k for k in inv_dict.keys() if "target_0" in k]

# %%
recovered_models = {}

for k in model_keys:
    recovered_models[k] = np.vstack([
        inv_dict[f"{k}_{ind}"] for ind in range(rx_locs.shape[0])
    ]).T

# %%
mesh_invert = discretize.TensorMesh([(np.r_[thicknesses1d, thicknesses1d[-1]])], origin="0")

# %%
with open("./synthetic-data-10m/true-models.pkl", "rb") as f:
    true_models = pickle.load(f)

# %%
tree_mesh = discretize.load_mesh("./synthetic-data-10m/treemesh.json")

# %%
key = "target_30"

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 6))

norm = LogNorm(vmin=1e-3, vmax=1/20)

plt.colorbar(ax[0].pcolor(
    rx_locs[:, 0], -mesh_invert.cell_centers, np.exp(recovered_models[key]), norm=norm
), ax=ax[0])

plt.colorbar(
    tree_mesh.plot_slice(
        true_models[key], pcolor_opts={"norm":norm}, ax=ax[1],
        normal="y"
    )[0], ax=ax[1]
)

for a in ax: 
    a.set_ylim(np.r_[-250, 0])
    a.set_xlim(np.r_[-500, 500])
    a.set_aspect(1)

# %%
# plot data misfits
