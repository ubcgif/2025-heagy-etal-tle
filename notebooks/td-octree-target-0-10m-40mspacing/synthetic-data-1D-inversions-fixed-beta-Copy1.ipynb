# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, Normalize
import time
import pickle

from concurrent.futures import ProcessPoolExecutor, as_completed

import discretize 
from simpeg.utils import mkvc, plot_1d_layer_model
from simpeg import (
    maps,
    Data,
    data_misfit,
    inverse_problem,
    regularization,
    optimization,
    directives,
    inversion,
    utils,
)
from simpeg.electromagnetics import time_domain as tdem
from simpeg.utils.solver_utils import get_default_solver

from simpeg.meta import MultiprocessingMetaSimulation #DaskMetaSimulation

# %%
# from inversions_1d import create_inversion, run_inv

# %%
Solver = get_default_solver()
Solver
# Out:
# pymatsolver.direct.pardiso.Pardiso

# %% [markdown]
# # load data

# %%
n_times_invert = 20

# %%
rx_locs = np.load("rx_locs.npy")

# %%
rx_locs[:, 0]
# Out:
# array([-400., -360., -320., -280., -240., -200., -160., -120.,  -80.,
#         -40.,    0.,   40.,   80.,  120.,  160.,  200.,  240.,  280.,
#         320.,  360.,  400., -400., -360., -320., -280., -240., -200.,
#        -160., -120.,  -80.,  -40.,    0.,   40.,   80.,  120.,  160.,
#         200.,  240.,  280.,  320.,  360.,  400., -400., -360., -320.,
#        -280., -240., -200., -160., -120.,  -80.,  -40.,    0.,   40.,
#          80.,  120.,  160.,  200.,  240.,  280.,  320.,  360.,  400.,
#        -400., -360., -320., -280., -240., -200., -160., -120.,  -80.,
#         -40.,    0.,   40.,   80.,  120.,  160.,  200.,  240.,  280.,
#         320.,  360.,  400., -400., -360., -320., -280., -240., -200.,
#        -160., -120.,  -80.,  -40.,    0.,   40.,   80.,  120.,  160.,
#         200.,  240.,  280.,  320.,  360.,  400., -400., -360., -320.,
#        -280., -240., -200., -160., -120.,  -80.,  -40.,    0.,   40.,
#          80.,  120.,  160.,  200.,  240.,  280.,  320.,  360.,  400.,
#        -400., -360., -320., -280., -240., -200., -160., -120.,  -80.,
#         -40.,    0.,   40.,   80.,  120.,  160.,  200.,  240.,  280.,
#         320.,  360.,  400., -400., -360., -320., -280., -240., -200.,
#        -160., -120.,  -80.,  -40.,    0.,   40.,   80.,  120.,  160.,
#         200.,  240.,  280.,  320.,  360.,  400., -400., -360., -320.,
#        -280., -240., -200., -160., -120.,  -80.,  -40.,    0.,   40.,
#          80.,  120.,  160.,  200.,  240.,  280.,  320.,  360.,  400.])

# %%
def load_obs_file(filepath):
    """
    Load a GIF-style .pre file (TDoctree format).

    Parameters
    ----------
    filepath : str
        Path to the .pre-style data file

    Returns
    -------
    dict
        {
            "ignore": float or None,
            "n_trx": int,
            "transmitters": list of {
                "location": list of float,
                "n_recv": int,
                "n_time": int,
                "receivers": list of {
                    "loc": (x, y, z),
                    "time": float,
                    "data": list of float
                }
            }
        }
    """
    with open(filepath, "r") as f:
        lines = [line.strip() for line in f if line.strip()]

    i = 0
    ignore_value = None
    transmitters = []

    # Parse IGNORE line if present
    if lines[i].startswith("IGNORE"):
        ignore_value = float(lines[i].split()[1])
        i += 1

    # Parse number of transmitters
    if lines[i].startswith("N_TRX"):
        n_trx = int(lines[i].split()[1])
        i += 1
    else:
        raise ValueError("Missing N_TRX line")

    while i < len(lines):
        if lines[i].startswith("TRX_LOOP"):
            i += 1
            location = list(map(float, lines[i].split()))
            i += 1
            if not lines[i].startswith("N_RECV"):
                raise ValueError("Expected N_RECV")
            n_recv = int(lines[i].split()[1])
            i += 1
            if not lines[i].startswith("N_TIME"):
                raise ValueError("Expected N_TIME")
            n_time = int(lines[i].split()[1])
            i += 1

            receivers = []
            for _ in range(n_recv * n_time):
                parts = lines[i].split()
                x, y, z = map(float, parts[0:3])
                time = float(parts[3])
                data = list(map(float, parts[4:]))
                receivers.append({
                    "loc": (x, y, z),
                    "time": time,
                    "data": data
                })
                i += 1

            transmitters.append({
                "location": location,
                "n_recv": n_recv,
                "n_time": n_time,
                "receivers": receivers
            })
        else:
            i += 1  # Skip unknown or empty lines

    return {
        "ignore": ignore_value,
        "n_trx": len(transmitters),
        "transmitters": transmitters
    }

# %%
dobs = load_obs_file("dobs.txt")

# %%
rx_times = np.array([dobs["transmitters"][0]["receivers"][j]["time"] for j in range(len(dobs["transmitters"][0]["receivers"]))])

# %%
rx_times
# Out:
# array([2.00000000e-05, 2.54854997e-05, 3.24755348e-05, 4.13827616e-05,
#        5.27330180e-05, 6.71963657e-05, 8.56266480e-05, 1.09111896e-04,
#        1.39038559e-04, 1.77173358e-04, 2.25767578e-04, 2.87689978e-04,
#        3.66596142e-04, 4.67144294e-04, 5.95270288e-04, 7.58538038e-04,
#        9.66586048e-04, 1.23169642e-03, 1.56951994e-03, 2.00000000e-03])

# %%
n_times_invert = len(rx_times)

# %% [markdown]
# # create survey

# %%
tx_height = rx_locs[0, 2]
source_list = []

for i in range(rx_locs.shape[0]): 
    rx = tdem.receivers.PointMagneticFluxTimeDerivative(rx_locs[i, :], rx_times, orientation="z")
    src = tdem.sources.CircularLoop(
        receiver_list=[rx], location=rx_locs[i, :], orientation="z", radius=10, 
        waveform=tdem.sources.StepOffWaveform()
    )
    source_list.append(src)

full_survey = tdem.Survey(source_list)

# %%
dobs_values = np.zeros((n_times_invert, len(dobs["transmitters"])))
for i in range(len(dobs["transmitters"])): 
    for j in range(n_times_invert): 
        dobs_values[j, i] = dobs["transmitters"][i]["receivers"][j]["data"][-2]

# %%
relative_error = 0.1
noise_floor = 1e-11
observed_data = Data(survey=full_survey, dobs=-discretize.utils.mkvc(dobs_values), relative_error=relative_error, noise_floor=noise_floor)

# %%
ind = 25
rx_locs[ind, :]
# Out:
# array([-240., -120.,   30.])

# %%
ubc_mesh = discretize.TreeMesh.read_UBC("octree_mesh.txt")
model = discretize.TreeMesh.read_model_UBC(ubc_mesh, "target_0.con")

# %%
len(full_survey.source_list)
# Out:
# 189

# %%
src_ind = int((len(full_survey.source_list) -1 )/2)
src_ind
# Out:
# 94

# %%
fig, ax = plt.subplots(1, 1)
plt.colorbar(
    ubc_mesh.plot_slice(
        model, ax=ax, pcolor_opts={"norm":LogNorm()}, 
        normal="Z", ind=1468
    )[0], 
    ax=ax
)

ax.set_xlim(1000*np.r_[-1, 1])
ax.set_ylim(1000*np.r_[-1, 1])

ax.plot(rx_locs[:, 0], rx_locs[:, 1], "wo", ms=4)
ax.plot(rx_locs[src_ind, 0], rx_locs[src_ind, 1], "rs", ms=6)

# %%
observed_data[src, src.receiver_list[0]]
# Out:
# array([-1.371970e-07, -7.916234e-08, -4.415389e-08, -2.604280e-08,
#        -1.529092e-08, -8.892061e-09, -5.140648e-09, -2.949207e-09,
#        -1.633290e-09, -9.484335e-10, -5.375306e-10, -2.998337e-10,
#        -1.657136e-10, -8.865579e-11, -4.985188e-11, -2.764513e-11,
#        -1.519808e-11, -8.161266e-12, -4.627393e-12, -2.566069e-12])

# %%
for src_ind in range(180): 
    src = full_survey.source_list[src_ind]
    
    # plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
    plt.loglog(rx_times, -observed_data[src, src.receiver_list[0]], "C0-o", ms=4, alpha=0.1)

# %%
thicknesses_true = np.r_[60, 40]
sigma_true = 1./np.r_[500, 20, 500]

# %%
src_ind = 90
source_sounding = full_survey.source_list[src_ind]
survey_sounding = tdem.Survey([source_sounding])
sim1d_true = tdem.Simulation1DLayered(
    survey=survey_sounding, thicknesses=thicknesses_true, sigmaMap=maps.IdentityMap(nP=3)
)

# %%
dpred_halfspace = sim1d_true.dpred(1./500*np.ones(3))

# %%
dpred_1d = sim1d_true.dpred(sigma_true)

# %%
fig, ax = plt.subplots(1, 1)

ax.loglog(rx_times, -dpred_halfspace, "k-o", ms=4, label="halfspace")
ax.loglog(rx_times, -observed_data[source_sounding, source_sounding.receiver_list[0]], "C0-o", ms=4, label="dobs")
ax.loglog(rx_times, -dpred_1d, "C1-o", ms=4, label="1D")

ax.legend()

# %%
# octree_mesh = discretize.load_mesh("./synthetic-data/treemesh.json")

# octree_mesh = discretize.load_mesh()

# %%
cs = 10
core_region = 200
npad = 10
padding_factor = 1.3

thicknesses1d = discretize.utils.unpack_widths(
    [(cs, np.int64(np.ceil(core_region/cs))), (cs, npad, padding_factor)]
)

# %%
np.sum(thicknesses1d)
# Out:
# np.float64(754.0534646790002)

# %%
# set up 1D inversion 
def create_inversion(
    ind,
    dobs,
    rx_times_invert=rx_times[:n_times_invert],
    rx_locs=rx_locs, 
    relative_error=0.05,
    noise_floor=1e-13,
    alpha_s = 1e-2,
    alpha_x = 1,
    rho_back = 500,
    beta0 = 1,
): 
    cs = 10
    core_region = 200
    npad = 10
    padding_factor = 1.3
    
    thicknesses1d = discretize.utils.unpack_widths(
        [(cs, np.int64(np.ceil(core_region/cs))), (cs, npad, padding_factor)]
    )
    
    rx_sounding = tdem.receivers.PointMagneticFluxTimeDerivative(
        locations=rx_locs[ind, :], times=rx_times_invert, orientation="z"
    )
    src_sounding = tdem.sources.CircularLoop(
        receiver_list=[rx_sounding], location=rx_locs[ind, :], orientation="z", 
        radius=10, 
        waveform=tdem.sources.StepOffWaveform()
    )
    survey_sounding = tdem.Survey([src_sounding])
    mesh_invert = discretize.TensorMesh([(np.r_[thicknesses1d, thicknesses1d[-1]])], origin="0")
    
    sim1d = tdem.Simulation1DLayered(
        survey=survey_sounding, thicknesses=thicknesses1d, sigmaMap=maps.ExpMap(mesh_invert)
    )

    data_invert = Data(
        survey_sounding, 
        dobs=dobs,
        standard_deviation=relative_error*np.abs(dobs) + noise_floor
    )
    
    dmis = data_misfit.L2DataMisfit(simulation=sim1d, data=data_invert)
    reg = regularization.WeightedLeastSquares(
        mesh_invert, alpha_s=alpha_s, alpha_x=alpha_x, 
        # reference_model=np.log(1./rho_back),
        # norms=norms
    )
    
    opt = optimization.InexactGaussNewton(maxIter=20)
    inv_prob = inverse_problem.BaseInvProblem(dmis, reg, opt, beta=beta0)
    
    # Defining a starting value for the trade-off parameter (beta) between the data
    # misfit and the regularization.
    # starting_beta = directives.BetaEstimate_ByEig(beta0_ratio=10)
    
    # cool_beta = directives.BetaSchedule(coolingFactor=1.5, coolingRate=1)
    
    # Update the preconditionner
    update_Jacobi = directives.UpdatePreconditioner()
    
    # Options for outputting recovered models and predicted data for each beta.
    save_iteration = directives.SaveOutputDictEveryIteration(
        saveOnDisk=False,
    )
    
    
    # Updating the preconditionner if it is model dependent.
    update_jacobi = directives.UpdatePreconditioner()
    
    # Add sensitivity weights
    sensitivity_weights = directives.UpdateSensitivityWeights()
    
    target_misfit = directives.TargetMisfit()
    
    # The directives are defined as a list.
    directives_list = [
        sensitivity_weights,
        update_jacobi,
        # starting_beta,
        # cool_beta,
        save_iteration,
        target_misfit,
    ]
    
    # Here we combine the inverse problem and the set of directives
    inv = inversion.BaseInversion(inv_prob, directives_list)
    return inv

# %%
ind = 90
source_sounding = full_survey.source_list[ind]
inv = create_inversion(
    ind, observed_data[source_sounding, source_sounding.receiver_list[0]], 
    rx_times[:n_times_invert], rx_locs
)

# %%
rho_start = 500
m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
mopt = inv.run(m0)
# Out:
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.01e+03  0.00e+00  1.01e+03    8.35e+02      0
#    1  1.00e+00  6.91e+02  4.55e-01  6.91e+02    1.76e+03      0
#    2  1.00e+00  1.02e+02  3.95e-01  1.03e+02    1.55e+02      0
#    3  1.00e+00  7.82e+01  7.26e-01  7.90e+01    1.98e+02      2   Skip BFGS
#    4  1.00e+00  6.37e+01  1.88e+00  6.56e+01    2.72e+02      1   Skip BFGS
#    5  1.00e+00  3.23e+01  2.74e+00  3.51e+01    3.44e+01      0   Skip BFGS
#    6  1.00e+00  2.83e+01  2.48e+00  3.08e+01    9.97e+01      2   Skip BFGS
#    7  1.00e+00  2.33e+01  3.94e+00  2.72e+01    1.19e+02      1   Skip BFGS
#    8  1.00e+00  2.31e+01  3.19e+00  2.62e+01    1.27e+02      2   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0061e+02
# 1 : |xc-x_last| = 1.0514e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.2730e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.2730e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      9
# ------------------------- DONE! -------------------------

# %%
iterations = len(inv.directiveList.dList[-2].outDict)

# %%
# plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
# plt.loglog(rx_times, -data_dict[key][src, rx], "C0o", ms=4)
rx_times_invert = rx_times[:n_times_invert]
plt.errorbar(rx_times_invert, -inv.invProb.dmisfit[0][1].data.dobs, yerr=inv.invProb.dmisfit[0][1].data.standard_deviation)
plt.loglog(rx_times_invert, -inv.directiveList.dList[-2].outDict[iterations]["dpred"], "C1-s", ms=4)

# %%
fig, ax = plt.subplots(1, 1, figsize=(2, 4))
plot_1d_layer_model(
    thicknesses1d, np.exp(mopt), ax=ax, color="C0", label="recovered"
)
plot_1d_layer_model(
    thicknesses_true, sigma_true, ax=ax, color="k", label="true"
)
ax.set_ylim([400, 0])
ax.set_xlim([1e-4, 1e-1])
# Out:
# (0.0001, 0.1)

# %%
ind = 91
source_sounding = full_survey.source_list[ind]
inv = create_inversion(
    ind, observed_data[source_sounding, source_sounding.receiver_list[0]], rx_times[:n_times_invert], rx_locs
)

# %%
rho_start = 500
m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)
mopt = inv.run(m0)
# Out:
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.36e+03  0.00e+00  1.36e+03    8.36e+02      0
#    1  1.00e+00  6.60e+02  2.16e-01  6.60e+02    5.87e+02      2
#    2  1.00e+00  6.21e+02  1.72e+00  6.22e+02    1.25e+03      1
#    3  1.00e+00  2.14e+02  6.61e+00  2.21e+02    7.10e+02      0
#    4  1.00e+00  1.14e+02  7.50e+00  1.21e+02    6.12e+01      0   Skip BFGS
#    5  1.00e+00  1.07e+02  5.69e+00  1.13e+02    2.91e+02      2   Skip BFGS
#    6  1.00e+00  1.00e+02  5.68e+00  1.06e+02    3.28e+02      3   Skip BFGS
#    7  1.00e+00  6.99e+01  7.59e+00  7.74e+01    7.87e+01      0   Skip BFGS
#    8  1.00e+00  6.63e+01  6.53e+00  7.29e+01    1.18e+02      3   Skip BFGS
#    9  1.00e+00  6.35e+01  6.39e+00  6.99e+01    1.71e+02      3   Skip BFGS
#   10  1.00e+00  6.19e+01  6.42e+00  6.83e+01    2.12e+02      3   Skip BFGS
#   11  1.00e+00  5.38e+01  7.05e+00  6.09e+01    1.31e+01      0
#   12  1.00e+00  5.20e+01  6.27e+00  5.82e+01    1.09e+02      3   Skip BFGS
#   13  1.00e+00  5.05e+01  6.63e+00  5.71e+01    1.35e+02      3   Skip BFGS
#   14  1.00e+00  4.62e+01  7.66e+00  5.38e+01    1.38e+01      0   Skip BFGS
#   15  1.00e+00  4.52e+01  6.62e+00  5.18e+01    8.64e+01      3   Skip BFGS
#   16  1.00e+00  4.40e+01  6.81e+00  5.08e+01    1.03e+02      3   Skip BFGS
#   17  1.00e+00  4.22e+01  7.08e+00  4.93e+01    9.76e+00      0
#   18  1.00e+00  4.16e+01  6.65e+00  4.83e+01    3.71e+01      3   Skip BFGS
#   19  1.00e+00  4.05e+01  7.46e+00  4.79e+01    8.87e+01      2   Skip BFGS
#   20  1.00e+00  3.93e+01  7.72e+00  4.70e+01    8.20e+00      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 9.1100e-01 <= tolF*(1+|f0|) = 1.3603e+02
# 1 : |xc-x_last| = 2.4716e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 8.2039e+00 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.2039e+00 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      20    <= iter          =     20
# ------------------------- DONE! -------------------------

# %%
fig, ax = plt.subplots(1, 1, figsize=(2, 4))
plot_1d_layer_model(
    thicknesses1d, np.exp(mopt), ax=ax, color="C0", label="recovered"
)
plot_1d_layer_model(
    thicknesses_true, sigma_true, ax=ax, color="k", label="true"
)
ax.set_ylim([400, 0])
ax.set_xlim([1e-4, 1e-1])
# Out:
# (0.0001, 0.1)

# %%
# plt.loglog(rx_times, -data_dict["background"][src, src.receiver_list[0]], "k", alpha=0.5)
# plt.loglog(rx_times, -data_dict[key][src, rx], "C0o", ms=4)
rx_times_invert = rx_times[:n_times_invert]
plt.errorbar(rx_times_invert, -inv.invProb.dmisfit[0][1].data.dobs, yerr=inv.invProb.dmisfit[0][1].data.standard_deviation)
plt.loglog(rx_times_invert, -inv.directiveList.dList[-2].outDict[iterations]["dpred"], "C1-s", ms=4)

# %%
rho_start = 500
m0 = np.log(1/rho_start) * np.ones(len(thicknesses1d)+1)

# %%
directory = "/t40array/lheagy/2025-heagy-et-al-tle/target-0-invs-1d"

# %%
def run_inv(ind, dobs, m0, directory=directory): 
    inv = create_inversion(ind, dobs)
    
    label_key=f"{ind}"
    
    mopt = inv.run(m0)
    np.save(f"{directory}/{label_key}_model.npy", mopt)
    
    inv_dict = inv.directiveList.dList[-2].outDict
    with open(f"{directory}/{label_key}_inv_dict.pkl", "wb") as f:
        pickle.dump(inv_dict, f)

    return label_key, mopt

# %%
ind=0
src = full_survey.source_list[ind]
rx = src.receiver_list[0]
run_inv(0, observed_data[src, rx], m0, directory)
# Out:
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.79e+01  0.00e+00  5.79e+01    3.24e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.8927e+00
# 1 : |xc-x_last| = 4.9713e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.2354e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.2354e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
# ('0',
#  array([-6.18070666, -6.1799889 , -6.17798547, -6.17475994, -6.17025895,
#         -6.16445547, -6.15741603, -6.14935811, -6.14065575, -6.13176047,
#         -6.12306289, -6.11478036, -6.10694083, -6.09945302, -6.09219803,
#         -6.08509039, -6.07809666, -6.07122577, -6.06450944, -6.05776051,
#         -6.08657275, -6.10968133, -6.12812658, -6.14280961, -6.15447537,
#         -6.1636715 , -6.17079606, -6.17616994, -6.1802772 , -6.18546719,
#         -6.28216455]))

# %%
from joblib import Parallel, delayed
inv_dict = {}
results = Parallel(n_jobs=48, backend='loky')(  # 'loky' is the default and most flexible
    delayed(run_inv)(
        ind, observed_data[full_survey.source_list[ind], 
        full_survey.source_list[ind].receiver_list[0]], 
        m0, directory)
    for ind in range(rx_locs.shape[0])
)

# Collect results
for (label_key, mopt) in results:
    inv_dict[label_key] = mopt
# Out:
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.71e+02  0.00e+00  8.71e+02    8.32e+02      0
#    1  1.00e+00  1.53e+02  2.02e-01  1.53e+02    2.63e+02      1
#    2  1.00e+00  6.93e+01  6.73e-01  7.00e+01    3.27e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.7206e+01
# 1 : |xc-x_last| = 1.0868e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.2734e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.2734e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      3
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.83e+01  0.00e+00  6.83e+01    3.50e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.9289e+00
# 1 : |xc-x_last| = 5.1078e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.4982e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.4982e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.59e+02  0.00e+00  1.59e+02    5.13e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.6049e+01
# 1 : |xc-x_last| = 7.9908e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.1289e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1289e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.58e+01  0.00e+00  7.58e+01    3.65e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.6777e+00
# 1 : |xc-x_last| = 5.7826e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.6468e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.6468e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.01e+02  0.00e+00  2.01e+02    5.55e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0233e+01
# 1 : |xc-x_last| = 9.6567e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.5453e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.5453e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  9.37e+01  0.00e+00  9.37e+01    3.96e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.4668e+00
# 1 : |xc-x_last| = 6.5887e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.9638e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.9638e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.53e+01  0.00e+00  7.53e+01    3.60e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.6278e+00
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.42e+01  0.00e+00  6.42e+01    3.37e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.5239e+00
# 1 : |xc-x_last| = 5.3206e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.3711e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.3711e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.78e+02  0.00e+00  3.78e+02    6.99e+02      0
#    1  1.00e+00  3.98e+01  9.60e-02  3.99e+01    2.83e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.7878e+01
# 1 : |xc-x_last| = 4.8593e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.8343e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.8343e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.12e+02  0.00e+00  2.12e+02    5.80e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.1269e+01
# 1 : |xc-x_last| = 8.9965e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.7984e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.7984e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  9.14e+01  0.00e+00  9.14e+01    4.00e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.2423e+00
# 1 : |xc-x_last| = 6.0096e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.9968e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.9968e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.69e+02  0.00e+00  3.69e+02    6.94e+02      0
#    1  1.00e+00  3.77e+01  9.29e-02  3.78e+01    2.74e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.7021e+01
# 1 : |xc-x_last| = 4.7845e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.7390e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7390e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.68e+01  0.00e+00  7.68e+01    3.67e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.7771e+00
# 1 : |xc-x_last| = 5.8239e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.6731e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.6731e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.78e+02  0.00e+00  3.78e+02    6.76e+02      0
#    1  1.00e+00  4.06e+01  9.64e-02  4.07e+01    2.72e+02      0
# ------------------------- STOP! -------------------------
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.94e+01  0.00e+00  6.94e+01    3.49e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.0405e+00
# 1 : |xc-x_last| = 5.5532e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.4893e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.4893e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.11e+02  0.00e+00  6.11e+02    7.95e+02      0
#    1  1.00e+00  1.35e+02  1.93e-01  1.35e+02    5.94e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.1242e+01
# 1 : |xc-x_last| = 7.7265e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.9427e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.9427e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.38e+02  0.00e+00  1.38e+02    4.82e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3863e+01
# 1 : |xc-x_last| = 7.2675e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.8199e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.8199e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.14e+02  0.00e+00  1.14e+02    4.44e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1515e+01
# 1 : |xc-x_last| = 6.6791e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.4365e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.4365e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.16e+01  0.00e+00  6.16e+01    3.33e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.2604e+00
# 1 : |xc-x_last| = 5.1493e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.3296e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.3296e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.96e+02  0.00e+00  2.96e+02    6.37e+02      0
#    1  1.00e+00  2.31e+01  6.72e-02  2.31e+01    1.94e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.9715e+01
# 1 : |xc-x_last| = 9.5828e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.9437e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9437e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.84e+02  0.00e+00  3.84e+02    6.78e+02      0
#    1  1.00e+00  4.21e+01  9.88e-02  4.22e+01    2.78e+02      0
# ------------------------- STOP! -------------------------
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  4.68e+02  0.00e+00  4.68e+02    7.37e+02      0
#    1  1.00e+00  6.50e+01  1.28e-01  6.52e+01    3.70e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.6929e+01
# 1 : |xc-x_last| = 1.4265e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.7032e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.7032e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.66e+02  0.00e+00  2.66e+02    6.31e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6685e+01
# 1 : |xc-x_last| = 1.0447e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 6.3066e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.3066e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.97e+01  0.00e+00  8.97e+01    3.96e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.0733e+00
# 1 : |xc-x_last| = 5.9685e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.9581e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.9581e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.29e+02  0.00e+00  2.29e+02    5.92e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.3001e+01
# 1 : |xc-x_last| = 9.8564e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.9240e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.9240e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.35e+02  0.00e+00  1.35e+02    4.71e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3602e+01
# 1 : |xc-x_last| = 7.6815e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.7066e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.7066e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.01e+02  0.00e+00  1.01e+02    4.16e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0210e+01
# 1 : |xc-x_last| = 6.5049e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.1604e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.1604e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.16e+02  0.00e+00  6.16e+02    7.65e+02      0
#    1  1.00e+00  1.00e+02  1.06e-01  1.00e+02    3.19e+02      1
#    2  1.00e+00  2.14e+01  3.52e-01  2.18e+01    1.79e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------

# %%
inv_dict["50"]
# Out:
# array([-6.16670708, -6.1469596 , -6.0967205 , -6.01136521, -5.88482361,
#        -5.71830712, -5.52905723, -5.35045769, -5.21732385, -5.15046181,
#        -5.15475015, -5.2254687 , -5.35473921, -5.53619035, -5.76775155,
#        -6.05295964, -6.40132424, -6.82685033, -7.33900078, -7.89622461,
#        -8.04026893, -8.08047832, -8.02675459, -7.88809592, -7.67290278,
#        -7.38454036, -7.01923763, -6.56716339, -6.01814189, -5.397159  ,
#        -5.98784851])
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.01e+02  0.00e+00  1.01e+02    4.16e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0247e+01
# 1 : |xc-x_last| = 6.5464e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.1587e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.1587e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.28e+02  0.00e+00  8.28e+02    8.27e+02      0
#    1  1.00e+00  3.66e+02  3.25e-01  3.66e+02    1.13e+03      0
#    2  1.00e+00  5.66e+01  2.66e-01  5.69e+01    7.60e+01      0
#    3  1.00e+00  3.83e+01  6.53e-01  3.90e+01    1.94e+02      1   Skip BFGS
#    4  1.00e+00  2.18e+01  1.76e+00  2.36e+01    1.58e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.2926e+01
# 1 : |xc-x_last| = 7.8025e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.5845e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.5845e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      5
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.92e+02  0.00e+00  1.92e+02    5.44e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.9275e+01
# 1 : |xc-x_last| = 9.3721e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.4384e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.4384e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.35e+02  0.00e+00  1.35e+02    4.76e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3623e+01
# 1 : |xc-x_last| = 7.4736e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.7612e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.7612e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.78e+02  0.00e+00  1.78e+02    5.17e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7879e+01
# 1 : |xc-x_last| = 9.6385e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.1675e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1675e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.57e+01  0.00e+00  8.57e+01    3.85e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.6703e+00
# 1 : |xc-x_last| = 6.2066e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.8480e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.8480e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  9.95e+02  0.00e+00  9.95e+02    8.63e+02      0
#    1  1.00e+00  5.70e+02  4.09e-01  5.70e+02    1.47e+03      0
#    2  1.00e+00  6.92e+01  4.10e-01  6.96e+01    1.99e+02      0
#    3  1.00e+00  3.65e+01  6.83e-01  3.72e+01    2.26e+02      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.9567e+01
# 1 : |xc-x_last| = 1.9944e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.2631e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.2631e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      4
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.65e+02  0.00e+00  3.65e+02    6.92e+02      0
#    1  1.00e+00  3.49e+01  9.03e-02  3.50e+01    2.64e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.6609e+01
# 1 : |xc-x_last| = 1.0941e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.6367e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6367e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  4.49e+02  0.00e+00  4.49e+02    7.26e+02      0
#    1  1.00e+00  5.97e+01  1.20e-01  5.98e+01    3.48e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.4986e+01
# 1 : |xc-x_last| = 1.4031e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.4823e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.4823e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.66e+02  0.00e+00  2.66e+02    5.99e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.6712e+01
# 1 : |xc-x_last| = 1.2635e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.9914e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.9914e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.79e+01  0.00e+00  5.79e+01    3.24e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.8927e+00
# 1 : |xc-x_last| = 4.9713e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.2354e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.2354e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.19e+01  0.00e+00  7.19e+01    3.57e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.2917e+00
# 1 : |xc-x_last| = 5.5927e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.5678e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.5678e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.17e+02  0.00e+00  5.17e+02    7.57e+02      0
#    1  1.00e+00  1.04e+02  1.63e-01  1.04e+02    5.15e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.1753e+01
# 1 : |xc-x_last| = 7.0267e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.1508e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.1508e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.36e+01  0.00e+00  8.36e+01    3.83e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.4561e+00
# 1 : |xc-x_last| = 5.7774e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.8287e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.8287e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.20e+01  0.00e+00  7.20e+01    3.57e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.3042e+00
# 1 : |xc-x_last| = 5.6014e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.5712e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.5712e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.74e+02  0.00e+00  7.74e+02    8.20e+02      0
#    1  1.00e+00  1.29e+02  1.60e-01  1.29e+02    2.99e+02      1
#    2  1.00e+00  4.50e+01  5.27e-01  4.55e+01    2.63e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.7459e+01
# 1 : |xc-x_last| = 7.5769e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.6283e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.6283e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      3
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  4.49e+02  0.00e+00  4.49e+02    6.97e+02      0
#    1  1.00e+00  2.82e+02  2.67e-01  2.82e+02    8.16e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.4985e+01
# 1 : |xc-x_last| = 1.3360e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 8.1624e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.1624e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.24e+02  0.00e+00  8.24e+02    8.27e+02      0
#    1  1.00e+00  3.65e+02  3.24e-01  3.65e+02    1.13e+03      0
#    2  1.00e+00  5.74e+01  2.63e-01  5.76e+01    7.67e+01      0
#    3  1.00e+00  4.11e+01  6.66e-01  4.18e+01    2.09e+02      1   Skip BFGS
#    4  1.00e+00  2.33e+01  1.84e+00  2.51e+01    1.70e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.2488e+01
# 1 : |xc-x_last| = 7.7874e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.6950e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.6950e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      5
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.00e+02  0.00e+00  3.00e+02    6.39e+02      0
#    1  1.00e+00  2.28e+01  6.82e-02  2.29e+01    1.95e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.0091e+01
# 1 : |xc-x_last| = 9.2746e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.9510e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9510e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.28e+02  0.00e+00  1.28e+02    4.51e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.2894e+01
# 1 : |xc-x_last| = 7.9570e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.5052e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.5052e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.34e+02  0.00e+00  6.34e+02    7.42e+02      0
#    1  1.00e+00  1.04e+02  1.25e-01  1.04e+02    2.75e+02      1
#    2  1.00e+00  3.69e+01  4.35e-01  3.74e+01    2.49e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.3500e+01
# 1 : |xc-x_last| = 6.4162e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.4879e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4879e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      3
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.06e+02  0.00e+00  5.06e+02    7.53e+02      0
#    1  1.00e+00  1.01e+02  1.59e-01  1.01e+02    5.06e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.0721e+01
# 1 : |xc-x_last| = 6.9154e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.0644e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.0644e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.13e+03  0.00e+00  1.13e+03    8.66e+02      0
#    1  1.00e+00  2.97e+02  3.50e-01  2.97e+02    3.60e+02      1
#    2  1.00e+00  1.99e+02  7.46e-01  2.00e+02    4.87e+02      1
#    3  1.00e+00  3.53e+01  1.54e+00  3.68e+01    1.64e+02      0   Skip BFGS
#    4  1.00e+00  2.48e+01  2.80e+00  2.76e+01    2.01e+02      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.1265e+02
# 1 : |xc-x_last| = 1.1136e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.0125e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.0125e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      5
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  4.57e+02  0.00e+00  4.57e+02    6.99e+02      0
#    1  1.00e+00  2.90e+02  2.70e-01  2.90e+02    8.28e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.5764e+01
# 1 : |xc-x_last| = 1.2713e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 8.2793e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 8.2793e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  4.48e+02  0.00e+00  4.48e+02    7.33e+02      0
#    1  1.00e+00  6.85e+01  1.29e-01  6.86e+01    3.98e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 4.4862e+01
# 1 : |xc-x_last| = 5.7987e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.9765e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.9765e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.81e+02  0.00e+00  2.81e+02    6.42e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.8193e+01
# 1 : |xc-x_last| = 1.0881e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 6.4165e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.4165e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.09e+03  0.00e+00  1.09e+03    8.65e+02      0
#    1  1.00e+00  2.68e+02  3.31e-01  2.68e+02    3.14e+02      1
#    2  1.00e+00  1.71e+02  7.06e-01  1.71e+02    4.24e+02      1
#    3  1.00e+00  3.13e+01  1.40e+00  3.27e+01    1.47e+02      0   Skip BFGS
#    4  1.00e+00  2.13e+01  2.55e+00  2.38e+01    1.77e+02      1   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.0907e+02
# 0 : |xc-x_last| = 4.2142e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.7722e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.7722e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      5
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  7.68e+02  0.00e+00  7.68e+02    8.22e+02      0
#    1  1.00e+00  1.28e+02  1.55e-01  1.28e+02    3.09e+02      1
#    2  1.00e+00  3.90e+01  5.06e-01  3.95e+01    2.46e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 7.6855e+01
# 1 : |xc-x_last| = 6.8256e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.4579e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.4579e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      3
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.30e+02  0.00e+00  1.30e+02    4.70e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.3079e+01
# 1 : |xc-x_last| = 7.0579e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.6987e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.6987e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.86e+02  0.00e+00  5.86e+02    7.86e+02      0
#    1  1.00e+00  1.21e+02  1.81e-01  1.21e+02    5.51e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.8662e+01
# 1 : |xc-x_last| = 7.5143e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.5134e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.5134e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  6.24e+02  0.00e+00  6.24e+02    7.89e+02      0
#    1  1.00e+00  1.42e+02  1.96e-01  1.42e+02    5.86e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 6.2507e+01
# 1 : |xc-x_last| = 9.0616e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.8639e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.8639e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.14e+02  0.00e+00  5.14e+02    7.36e+02      0
#    1  1.00e+00  3.56e+02  3.01e-01  3.56e+02    9.54e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.1500e+01
# 1 : |xc-x_last| = 1.3984e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 9.5408e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 9.5408e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# 1 : |xc-x_last| = 5.8509e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.5961e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.5961e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  9.00e+02  0.00e+00  9.00e+02    8.34e+02      0
#    1  1.00e+00  1.63e+02  2.16e-01  1.63e+02    2.53e+02      1
#    2  1.00e+00  6.56e+01  4.18e-01  6.60e+01    1.56e+02      1
#    3  1.00e+00  3.24e+01  1.07e+00  3.34e+01    2.71e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.0112e+01
# 1 : |xc-x_last| = 1.1484e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 2.7103e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 2.7103e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      4
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  8.45e+02  0.00e+00  8.45e+02    8.31e+02      0
#    1  1.00e+00  3.86e+02  3.34e-01  3.86e+02    1.17e+03      0
#    2  1.00e+00  5.87e+01  2.71e-01  5.89e+01    8.05e+01      0
#    3  1.00e+00  4.08e+01  6.68e-01  4.15e+01    2.05e+02      1   Skip BFGS
#    4  1.00e+00  3.83e+01  2.30e+00  4.06e+01    3.02e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 8.4563e+01
# 1 : |xc-x_last| = 1.1873e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 3.0170e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 3.0170e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      5
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.56e+02  0.00e+00  2.56e+02    5.94e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.5733e+01
# 1 : |xc-x_last| = 1.2139e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.9369e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.9369e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  3.00e+02  0.00e+00  3.00e+02    6.41e+02      0
#    1  1.00e+00  2.35e+01  6.88e-02  2.36e+01    1.99e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 3.0137e+01
# 1 : |xc-x_last| = 9.6431e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.9857e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.9857e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.97e+02  0.00e+00  1.97e+02    5.63e+02      0
# ...
#    7  1.00e+00  1.13e+02  7.63e+00  1.20e+02    3.28e+01      0
#    8  1.00e+00  1.13e+02  7.42e+00  1.20e+02    3.43e+02      2   Skip BFGS
#    9  1.00e+00  8.84e+01  9.67e+00  9.80e+01    5.36e+01      0
#   10  1.00e+00  8.50e+01  8.37e+00  9.33e+01    1.44e+02      3   Skip BFGS
#   11  1.00e+00  8.44e+01  8.19e+00  9.26e+01    2.34e+02      3   Skip BFGS
#   12  1.00e+00  7.64e+01  8.82e+00  8.52e+01    1.66e+01      0
#   13  1.00e+00  7.42e+01  8.24e+00  8.24e+01    9.26e+01      3   Skip BFGS
#   14  1.00e+00  7.26e+01  8.35e+00  8.09e+01    1.22e+02      3
#   15  1.00e+00  7.19e+01  7.99e+00  7.99e+01    1.40e+02      4   Skip BFGS
#   16  1.00e+00  7.10e+01  8.10e+00  7.91e+01    1.55e+02      4   Skip BFGS
#   17  1.00e+00  6.58e+01  9.85e+00  7.56e+01    4.25e+01      0   Skip BFGS
#   18  1.00e+00  6.60e+01  8.40e+00  7.44e+01    6.62e+01      3
#   19  1.00e+00  6.41e+01  1.01e+01  7.42e+01    1.58e+02      2
#   20  1.00e+00  6.10e+01  1.04e+01  7.14e+01    1.07e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 2.7693e+00 <= tolF*(1+|f0|) = 1.5427e+02
# 1 : |xc-x_last| = 3.7827e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.0677e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0677e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      20    <= iter          =     20
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.70e+02  0.00e+00  5.70e+02    7.31e+02      0
#    1  1.00e+00  9.49e+01  1.02e-01  9.50e+01    2.97e+02      1
#    2  1.00e+00  2.52e+01  3.53e-01  2.56e+01    1.90e+02      0   Skip BFGS
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.7077e+01
# 1 : |xc-x_last| = 5.5686e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.8979e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.8979e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      3
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.34e+03  0.00e+00  1.34e+03    8.37e+02      0
#    1  1.00e+00  3.89e+02  1.77e-01  3.89e+02    3.93e+02      1
#    2  1.00e+00  2.51e+02  4.76e-01  2.52e+02    1.76e+02      2
#    3  1.00e+00  2.00e+02  1.29e+00  2.01e+02    2.27e+02      2   Skip BFGS
#    4  1.00e+00  1.75e+02  3.11e+00  1.78e+02    3.52e+02      2   Skip BFGS
#    5  1.00e+00  1.59e+02  4.75e+00  1.64e+02    4.57e+02      2   Skip BFGS
#    6  1.00e+00  7.87e+01  7.97e+00  8.67e+01    1.26e+02      0   Skip BFGS
#    7  1.00e+00  7.42e+01  6.63e+00  8.08e+01    1.68e+02      3   Skip BFGS
#    8  1.00e+00  7.13e+01  5.85e+00  7.72e+01    1.79e+02      3   Skip BFGS
#    9  1.00e+00  6.79e+01  6.07e+00  7.40e+01    2.03e+02      3   Skip BFGS
#   10  1.00e+00  6.66e+01  6.00e+00  7.26e+01    2.45e+02      3   Skip BFGS
#   11  1.00e+00  5.28e+01  7.87e+00  6.07e+01    2.43e+01      0   Skip BFGS
#   12  1.00e+00  5.19e+01  6.16e+00  5.80e+01    8.12e+01      3   Skip BFGS
#   13  1.00e+00  5.00e+01  6.58e+00  5.66e+01    1.13e+02      3   Skip BFGS
#   14  1.00e+00  4.92e+01  6.43e+00  5.56e+01    1.44e+02      3   Skip BFGS
#   15  1.00e+00  4.56e+01  6.89e+00  5.25e+01    9.89e+00      0
#   16  1.00e+00  4.47e+01  6.17e+00  5.09e+01    5.31e+01      3   Skip BFGS
#   17  1.00e+00  4.37e+01  6.33e+00  5.00e+01    8.92e+01      3
#   18  1.00e+00  4.30e+01  6.30e+00  4.93e+01    9.68e+01      3   Skip BFGS
#   19  1.00e+00  4.24e+01  6.34e+00  4.88e+01    1.15e+02      3   Skip BFGS
#   20  1.00e+00  4.03e+01  6.76e+00  4.71e+01    1.04e+01      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 1.7275e+00 <= tolF*(1+|f0|) = 1.3397e+02
# 1 : |xc-x_last| = 4.0941e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.0352e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0352e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      20    <= iter          =     20
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  9.84e+01  0.00e+00  9.84e+01    4.12e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 9.9405e+00
# 1 : |xc-x_last| = 6.3508e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 4.1205e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 4.1205e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  5.89e+02  0.00e+00  5.89e+02    7.89e+02      0
#    1  1.00e+00  1.22e+02  1.83e-01  1.22e+02    5.59e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 5.9008e+01
# 1 : |xc-x_last| = 7.4117e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.5879e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.5879e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      2
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.48e+03  0.00e+00  1.48e+03    8.32e+02      0
#    1  1.00e+00  7.21e+02  2.54e-01  7.21e+02    5.50e+02      2
#    2  1.00e+00  4.50e+02  8.77e-01  4.50e+02    2.75e+02      2
#    3  1.00e+00  3.60e+02  2.71e+00  3.62e+02    3.92e+02      2
#    4  1.00e+00  3.37e+02  7.72e+00  3.45e+02    9.40e+02      1   Skip BFGS
#    5  1.00e+00  1.32e+02  1.16e+01  1.43e+02    3.51e+02      0   Skip BFGS
#    6  1.00e+00  1.33e+02  6.22e+00  1.39e+02    4.26e+02      2   Skip BFGS
#    7  1.00e+00  9.16e+01  9.65e+00  1.01e+02    8.48e+01      0
#    8  1.00e+00  8.72e+01  7.87e+00  9.50e+01    1.63e+02      3   Skip BFGS
#    9  1.00e+00  8.45e+01  7.40e+00  9.19e+01    2.08e+02      3   Skip BFGS
#   10  1.00e+00  8.24e+01  7.40e+00  8.98e+01    2.58e+02      3   Skip BFGS
#   11  1.00e+00  7.13e+01  8.21e+00  7.95e+01    1.86e+01      0
#   12  1.00e+00  6.96e+01  7.41e+00  7.70e+01    8.19e+01      3   Skip BFGS
#   13  1.00e+00  6.69e+01  8.49e+00  7.54e+01    1.48e+02      3   Skip BFGS
#   14  1.00e+00  6.24e+01  9.20e+00  7.16e+01    1.48e+01      0
#   15  1.00e+00  6.21e+01  7.70e+00  6.98e+01    9.18e+01      3   Skip BFGS
#   16  1.00e+00  6.08e+01  8.17e+00  6.89e+01    1.16e+02      3   Skip BFGS
#   17  1.00e+00  6.04e+01  8.23e+00  6.87e+01    1.54e+02      2   Skip BFGS
#   18  1.00e+00  5.74e+01  8.71e+00  6.61e+01    1.18e+01      0
#   19  1.00e+00  5.68e+01  8.26e+00  6.51e+01    4.06e+01      2   Skip BFGS
#   20  1.00e+00  5.61e+01  8.23e+00  6.44e+01    6.45e+01      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 7.3506e-01 <= tolF*(1+|f0|) = 1.4831e+02
# 1 : |xc-x_last| = 2.0553e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 6.4453e+01 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 6.4453e+01 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      20    <= iter          =     20
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  2.05e+02  0.00e+00  2.05e+02    5.57e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 2.0589e+01
# 1 : |xc-x_last| = 9.7971e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.5749e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.5749e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.73e+02  0.00e+00  1.73e+02    5.36e+02      0
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 0.0000e+00 <= tolF*(1+|f0|) = 1.7363e+01
# 1 : |xc-x_last| = 8.0183e-01 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 5.3612e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 5.3612e+02 <= 1e3*eps       = 1.0000e-02
# 0 : maxIter   =      20    <= iter          =      1
# ------------------------- DONE! -------------------------
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# model has any nan: 0
# ============================ Inexact Gauss Newton ============================
#   #     beta     phi_d     phi_m       f      |proj(x-g)-x|  LS    Comment
# -----------------------------------------------------------------------------
# x0 has any nan: 0
#    0  1.00e+00  1.53e+03  0.00e+00  1.53e+03    8.30e+02      0
#    1  1.00e+00  7.46e+02  2.65e-01  7.47e+02    5.37e+02      2
#    2  1.00e+00  4.76e+02  9.20e-01  4.77e+02    2.74e+02      2
#    3  1.00e+00  3.94e+02  2.90e+00  3.97e+02    4.65e+02      2
#    4  1.00e+00  3.20e+02  4.88e+00  3.24e+02    5.73e+02      2   Skip BFGS
#    5  1.00e+00  1.85e+02  1.09e+01  1.96e+02    5.55e+02      0   Skip BFGS
#    6  1.00e+00  1.81e+02  5.91e+00  1.87e+02    6.15e+02      2   Skip BFGS
#    7  1.00e+00  1.11e+02  7.55e+00  1.18e+02    3.26e+01      0
#    8  1.00e+00  1.11e+02  7.26e+00  1.18e+02    3.35e+02      2   Skip BFGS
#    9  1.00e+00  8.66e+01  9.46e+00  9.60e+01    4.84e+01      0
#   10  1.00e+00  8.28e+01  8.38e+00  9.12e+01    1.19e+02      3   Skip BFGS
#   11  1.00e+00  8.23e+01  8.01e+00  9.03e+01    2.22e+02      3   Skip BFGS
#   12  1.00e+00  7.49e+01  8.62e+00  8.35e+01    1.67e+01      0
#   13  1.00e+00  7.26e+01  8.35e+00  8.09e+01    6.06e+01      3   Skip BFGS
#   14  1.00e+00  7.10e+01  8.26e+00  7.93e+01    1.14e+02      3
#   15  1.00e+00  7.15e+01  7.71e+00  7.92e+01    1.83e+02      3   Skip BFGS
#   16  1.00e+00  6.70e+01  8.32e+00  7.53e+01    1.68e+01      0
#   17  1.00e+00  6.57e+01  8.59e+00  7.43e+01    7.73e+01      2   Skip BFGS
#   18  1.00e+00  6.50e+01  8.40e+00  7.34e+01    8.95e+01      2
#   19  1.00e+00  6.38e+01  8.67e+00  7.25e+01    9.95e+01      2
#   20  1.00e+00  6.35e+01  8.17e+00  7.16e+01    1.09e+02      2
# ------------------------- STOP! -------------------------
# 1 : |fc-fOld| = 8.7846e-01 <= tolF*(1+|f0|) = 1.5320e+02
# 1 : |xc-x_last| = 2.3933e+00 <= tolX*(1+|x0|) = 3.5601e+00
# 0 : |proj(x-g)-x|    = 1.0908e+02 <= tolG          = 1.0000e-01
# 0 : |proj(x-g)-x|    = 1.0908e+02 <= 1e3*eps       = 1.0000e-02
# 1 : maxIter   =      20    <= iter          =     20
# ------------------------- DONE! -------------------------

# %%
# for ind in range(rx_locs.shape[0]): 
#     src = full_survey.source_list[ind]
#     rx = src.receiver_list[0]
#     label_key, mpot = run_inv(
#         ind, observed_data[src, rx], m0, directory
#     )
#     inv_dict[label_key] = mopt

# %%
# inv_dict = {}
# with ProcessPoolExecutor() as executor:
#     futures = []
#     for ind in range(rx_locs.shape[0]): 
#         src = full_survey.source_list[ind]
#         rx = src.receiver_list[0]
#         futures.append(
#             executor.submit(run_inv, ind, observed_data[src, rx], m0, directory)
#         )
            
#     for future in as_completed(futures):
#         label_key, mopt = future.result()
#         inv_dict[label_key] = mopt
# Out:
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
#
#
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# Running inversion with SimPEG v0.24.0
# Running inversion with SimPEG v0.24.0
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# Running inversion with SimPEG v0.24.0
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
# Running inversion with SimPEG v0.24.0
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
# simpeg.InvProblem will set Regularization.reference_model to m0.
# simpeg.InvProblem will set Regularization.reference_model to m0.
#
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
#
#
#
#
#
#                     simpeg.InvProblem is setting bfgsH0 to the inverse of the eval2Deriv.
#                     ***Done using the default solver Pardiso and no solver_opts.***
# simpeg.InvProblem will set Regularization.reference_model to m0.
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[46], line 12
#       7     futures.append(
#       8         executor.submit(run_inv, ind, observed_data[src, rx], m0, directory)
#       9     )
#      11 for future in as_completed(futures):
# ---> 12     label_key, mopt = future.result()
#      13     inv_dict[label_key] = mopt
#
# File ~/miniforge3/envs/py311/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniforge3/envs/py311/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
target_0_keys = [k for k in inv_dict.keys() if "target_0" in k]

# %%
recovered_models = {}

recovered_models = np.vstack([
    inv_dict[f"{ind}"] for ind in range(rx_locs.shape[0])
]).T

# %%
mesh_invert = discretize.TensorMesh([(np.r_[thicknesses1d, thicknesses1d[-1]])], origin="0")

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 6))

norm = LogNorm(vmin=1e-3, vmax=1/20)

plt.colorbar(ax[0].pcolor(
    rx_locs[:, 0], -mesh_invert.cell_centers, np.exp(recovered_models[key]), norm=norm
), ax=ax[0])

plt.colorbar(
    tree_mesh.plot_slice(
        true_models[key], pcolor_opts={"norm":norm}, ax=ax[1],
        normal="y"
    )[0], ax=ax[1]
)

for a in ax: 
    a.set_ylim(np.r_[-250, 0])
    a.set_xlim(np.r_[-500, 500])
    a.set_aspect(1)
